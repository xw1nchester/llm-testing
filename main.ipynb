# %%
import json
import math
import csv
import time
import datetime
import pandas as pd
from openai import OpenAI
from huggingface_hub import InferenceClient
from dotenv import load_dotenv
import os
import re
from pathlib import Path
from typing import Dict, Tuple, List
from collections import defaultdict
from tabulate import tabulate
from itertools import zip_longest

# %% [markdown]
# ## Тестирование LLM

# %%
load_dotenv()
hf_token = os.getenv("HF_TOKEN")
or_key = os.getenv("OR_KEY")

# %%
def strip_json_fence(text: str) -> str:
    return re.sub(r"^```(?:json)?\s*|\s*```$", "", text.strip(), flags=re.IGNORECASE)

# %%
def call_llm(base_url, api_key, model, system_message, prompt):
    client = OpenAI(
        base_url=base_url,
        api_key=api_key,
        timeout=1800
    )
    
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt},
        ],
        # temperature=0,
    )
    
    return completion.choices[0].message.content

# %%
def to_record_dict(data: list, key_fields: list):
    """
    Преобразует список объектов в словарь:
    (dynamic key) -> value

    key_fields: например
        ["subject", "year"]
        ["subject", "year", "month"]
        ["subject", "year", "month", "day"]
    """
    records = {}

    for item in data:
        try:
            key = tuple(item.get(field) for field in key_fields)
        except KeyError as e:
            raise ValueError(f"Missing key field {e} in item {item}")

        records[key] = item["value"]

    return records

# %%
def compute_basic_metrics(expected: Dict, predicted: Dict):
    expected_keys = set(expected.keys())
    predicted_keys = set(predicted.keys())

    tp_keys = expected_keys & predicted_keys
    fp_keys = predicted_keys - expected_keys
    fn_keys = expected_keys - predicted_keys

    TP = len(tp_keys)
    FP = len(fp_keys)
    FN = len(fn_keys)

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = (
        2 * precision * recall / (precision + recall)
        if (precision + recall) > 0
        else 0
    )

    return {
        "TP": TP,
        "FP": FP,
        "FN": FN,
        "TP_KEYS": tp_keys,
        "FN_KEYS": fn_keys,
        "FP_KEYS": fp_keys,
        "precision": round(precision, 4),
        "recall": round(recall, 4),
        "f1": round(f1, 4),
    }
    
# def get_differences(model_output, expected_data):
#     ref_dict = {(item['subject'], item['year']): item for item in expected_data}
#     model_dict = {(item['subject'], item['year']): item for item in model_output}
    
#     differences = []
#     for key, ref_item in ref_dict.items():
#         model_item = model_dict.get(key)
#         if model_item is None:
#             differences.append(('Ключ отсутствует в результате', key))
#         elif model_item != ref_item:
#             differences.append(('Есть различия', key, model_item, ref_item))

#     return differences

# %%
def save_json_data(directory, data):
    os.makedirs(directory, exist_ok=True)

    filename = os.path.join(
        directory,
        f"{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.json"
    )
    
    with open(filename, 'w', encoding='utf-8') as file:
        json.dump(data, file, ensure_ascii=False, indent=2)
        print(f"result saved to {filename}")

# %%
def call_llm_save_result_and_validate(base_url, api_key, model, indicator, sheet):
    try:
        indicator_name = indicator["name"]
        key_fields = indicator["key_fields"]

        print(f"{indicator_name} | sheet={sheet} | {model}")

        with open(f"./dataset/{indicator_name}/{sheet}/system.md", "r", encoding="utf-8") as file:
            system_message = file.read()

        with open(f"./dataset/{indicator_name}/{sheet}/input.csv", "r", encoding="utf-8") as file:
            data = file.read()

        with open(f"./dataset/{indicator_name}/{sheet}/expected.json", "r", encoding="utf-8") as file:
            expected_data = json.loads(file.read())

        start = time.perf_counter()
        content = call_llm(base_url, api_key, model, system_message, data)
        end = time.perf_counter()

        print(f"response content len: {len(content)}, duration: {int(end - start)}s")

        predicted_data = json.loads(strip_json_fence(content))

        model_name_safe = model.split(":")[0].replace("/", "-")
        directory = os.path.join("./dataset", indicator_name, sheet, "outputs", model_name_safe)
        os.makedirs(directory, exist_ok=True)

        save_json_data(directory, predicted_data)

        expected_records = to_record_dict(expected_data, key_fields)
        predicted_records = to_record_dict(predicted_data, key_fields)

        metrics = compute_basic_metrics(expected_records, predicted_records)

        print(
            f"TP={metrics['TP']}, FP={metrics['FP']}, "
            f"FN={metrics['FN']}, precision={metrics['precision']}, "
            f"recall={metrics['recall']}, f1={metrics['f1']}\n"
        )

        return metrics

    except Exception as e:
        print(f"Произошла ошибка: {e}\n")

# %%
indicators = [
    # Обучающая выборка
    {
        "name": "ВВП",
        "sheets": [
            1,
            2,
            3,
        ],
        "key_fields": ["subject", "year"]
    },
    {
        "name": "Индекс потребительских цен (за рассматриваемый период)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Индекс производства (оперативные данные)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Непродовольственные товары (за рассматриваемый период)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Непродовольственные товары (к декабрю предыдущего года)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Продовольственные товары (за рассматриваемый период)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Продовольственные товары (к декабрю предыдущего года)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Численность постоянного населения",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year"]
    },
    {
        "name": "Потребность работодателей",
        "sheets": ["Sheet1"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Ввод жилых домов",
        "sheets": [
            "июнь 2025",
            "июль2025",
            "август2025"
        ],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Cоциально-экономическое положение",
        "sheets": [
            "8",
            "11",
            "12"
        ],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Численность и состав рабочей силы",
        "sheets": ["Sheet1"],
        "key_fields": ["subject", "year"]
    },

    # Тестовая выборка
    {
        "name": "ВВП",
        "sheets": ["4"],
        "key_fields": ["subject", "year"]
    },
    {
        "name": "Реальная заработная плата",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Ожидаемая продолжительность жизни",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year"]
    },
    {
        "name": "Уровень зарегистрированной безработицы",
        "sheets": ["Sheet1"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Средний возраст",
        "sheets": ["1.11."],
        "key_fields": ["subject", "year"]
    },
    {
        "name": "Ввод жилых домов",
        "sheets": [
            "сентябрь2025",
        ],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Cоциально-экономическое положение",
        "sheets": [
            "16"
        ],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Численность не занятых",
        "sheets": ["Sheet1"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Число родившихся",
        "sheets": ["t1_2"],
        "key_fields": ["subject", "year"]
    },
]

# %% [markdown]
# ### OpenRouter

# %%
or_models = [
    # "qwen/qwen3-next-80b-a3b-instruct:free", # rate-limited
    # "qwen/qwen3-coder:free", # rate-limited
    "stepfun/step-3.5-flash:free",
    "nvidia/nemotron-3-nano-30b-a3b:free",
    "z-ai/glm-4.5-air:free",
    # "google/gemma-3-27b-it:free", # rate-limited
    "arcee-ai/trinity-large-preview:free",
    # "openrouter/aurora-alpha", # закончился тестовый период
    # "mistralai/mistral-small-3.1-24b-instruct:free", # rate-limited
    # "openrouter/pony-alpha", # 404
    # "openai/gpt-oss-120b:free", # 404
    # "openai/gpt-oss-20b:free", # 404
    # "arcee-ai/trinity-mini:free", # invalid JSON
    # "xiaomi/mimo-v2-flash:free", # стала платной
    # "mistralai/devstral-2512:free", # стала платной
    # "nvidia/nemotron-nano-9b-v2:free", # плохо себя показала
    # "meta-llama/llama-3.3-70b-instruct:free", # плохо себя показала
    # "nvidia/nemotron-nano-12b-v2-vl:free", # плохо себя показала,
    # "deepseek/deepseek-r1-0528:free", # invalid JSON
    # "meta-llama/llama-3.2-3b-instruct:free", # rate-limited
    # "nousresearch/hermes-3-llama-3.1-405b:free", # rate-limited
    # "qwen/qwen3-4b:free" # rate-limited
]

# %%
for indicator in indicators:
    for sheet in indicator["sheets"]:
        for model in or_models:
            call_llm_save_result_and_validate(
                base_url="https://openrouter.ai/api/v1",
                api_key=or_key,
                model=model,
                indicator=indicator,
                sheet=sheet
            )
# Out:
# Реальная заработная плата | sheet=Данные | stepfun/step-3.5-flash:free
# response content len: 391, duration: 13s
# result saved to ./dataset\Реальная заработная плата\Данные\outputs\stepfun-step-3.5-flash\2026-02-27_14-43-03.json
# TP=4, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Реальная заработная плата | sheet=Данные | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 391, duration: 10s
# result saved to ./dataset\Реальная заработная плата\Данные\outputs\nvidia-nemotron-3-nano-30b-a3b\2026-02-27_14-43-14.json
# TP=4, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Реальная заработная плата | sheet=Данные | z-ai/glm-4.5-air:free
# response content len: 391, duration: 68s
# result saved to ./dataset\Реальная заработная плата\Данные\outputs\z-ai-glm-4.5-air\2026-02-27_14-44-22.json
# TP=4, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Реальная заработная плата | sheet=Данные | arcee-ai/trinity-large-preview:free
# response content len: 319, duration: 5s
# result saved to ./dataset\Реальная заработная плата\Данные\outputs\arcee-ai-trinity-large-preview\2026-02-27_14-44-28.json
# TP=4, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ожидаемая продолжительность жизни | sheet=Данные | stepfun/step-3.5-flash:free
# response content len: 1991, duration: 32s
# result saved to ./dataset\Ожидаемая продолжительность жизни\Данные\outputs\stepfun-step-3.5-flash\2026-02-27_14-45-00.json
# TP=13, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ожидаемая продолжительность жизни | sheet=Данные | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 1926, duration: 19s
# result saved to ./dataset\Ожидаемая продолжительность жизни\Данные\outputs\nvidia-nemotron-3-nano-30b-a3b\2026-02-27_14-45-20.json
# TP=13, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ожидаемая продолжительность жизни | sheet=Данные | z-ai/glm-4.5-air:free
# response content len: 2199, duration: 141s
# result saved to ./dataset\Ожидаемая продолжительность жизни\Данные\outputs\z-ai-glm-4.5-air\2026-02-27_14-47-41.json
# TP=13, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ожидаемая продолжительность жизни | sheet=Данные | arcee-ai/trinity-large-preview:free
# response content len: 2407, duration: 38s
# result saved to ./dataset\Ожидаемая продолжительность жизни\Данные\outputs\arcee-ai-trinity-large-preview\2026-02-27_14-48-20.json
# TP=13, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Уровень зарегистрированной безработицы | sheet=Sheet1 | stepfun/step-3.5-flash:free
# response content len: 20840, duration: 306s
# result saved to ./dataset\Уровень зарегистрированной безработицы\Sheet1\outputs\stepfun-step-3.5-flash\2026-02-27_14-53-26.json
# TP=288, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Уровень зарегистрированной безработицы | sheet=Sheet1 | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 20426, duration: 357s
# result saved to ./dataset\Уровень зарегистрированной безработицы\Sheet1\outputs\nvidia-nemotron-3-nano-30b-a3b\2026-02-27_14-59-23.json
# TP=282, FP=0, FN=6, precision=1.0, recall=0.9792, f1=0.9895
#
# Уровень зарегистрированной безработицы | sheet=Sheet1 | z-ai/glm-4.5-air:free
# response content len: 22856, duration: 1270s
# result saved to ./dataset\Уровень зарегистрированной безработицы\Sheet1\outputs\z-ai-glm-4.5-air\2026-02-27_15-20-34.json
# TP=288, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Уровень зарегистрированной безработицы | sheet=Sheet1 | arcee-ai/trinity-large-preview:free
# response content len: 20473, duration: 291s
# result saved to ./dataset\Уровень зарегистрированной безработицы\Sheet1\outputs\arcee-ai-trinity-large-preview\2026-02-27_15-25-25.json
# TP=282, FP=6, FN=6, precision=0.9792, recall=0.9792, f1=0.9792
#
# Средний возраст | sheet=1.11. | stepfun/step-3.5-flash:free
# response content len: 6642, duration: 44s
# result saved to ./dataset\Средний возраст\1.11.\outputs\stepfun-step-3.5-flash\2026-02-27_15-26-09.json
# TP=96, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Средний возраст | sheet=1.11. | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 6161, duration: 75s
# result saved to ./dataset\Средний возраст\1.11.\outputs\nvidia-nemotron-3-nano-30b-a3b\2026-02-27_15-27-25.json
# TP=95, FP=1, FN=1, precision=0.9896, recall=0.9896, f1=0.9896
#
# Средний возраст | sheet=1.11. | z-ai/glm-4.5-air:free
# response content len: 6642, duration: 373s
# result saved to ./dataset\Средний возраст\1.11.\outputs\z-ai-glm-4.5-air\2026-02-27_15-33-38.json
# TP=96, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Средний возраст | sheet=1.11. | arcee-ai/trinity-large-preview:free
# response content len: 9714, duration: 152s
# result saved to ./dataset\Средний возраст\1.11.\outputs\arcee-ai-trinity-large-preview\2026-02-27_15-36-10.json
# TP=96, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ввод жилых домов | sheet=сентябрь2025 | stepfun/step-3.5-flash:free
# response content len: 9845, duration: 100s
# result saved to ./dataset\Ввод жилых домов\сентябрь2025\outputs\stepfun-step-3.5-flash\2026-02-27_15-37-51.json
# TP=96, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ввод жилых домов | sheet=сентябрь2025 | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 7361, duration: 158s
# result saved to ./dataset\Ввод жилых домов\сентябрь2025\outputs\nvidia-nemotron-3-nano-30b-a3b\2026-02-27_15-40-29.json
# TP=96, FP=1, FN=0, precision=0.9897, recall=1.0, f1=0.9948
#
# Ввод жилых домов | sheet=сентябрь2025 | z-ai/glm-4.5-air:free
# response content len: 9845, duration: 782s
# result saved to ./dataset\Ввод жилых домов\сентябрь2025\outputs\z-ai-glm-4.5-air\2026-02-27_15-53-31.json
# TP=96, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ввод жилых домов | sheet=сентябрь2025 | arcee-ai/trinity-large-preview:free
# response content len: 9755, duration: 161s
# result saved to ./dataset\Ввод жилых домов\сентябрь2025\outputs\arcee-ai-trinity-large-preview\2026-02-27_15-56-13.json
# TP=96, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Cоциально-экономическое положение | sheet=16 | stepfun/step-3.5-flash:free
# response content len: 2059, duration: 44s
# result saved to ./dataset\Cоциально-экономическое положение\16\outputs\stepfun-step-3.5-flash\2026-02-27_15-56-58.json
# TP=20, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Cоциально-экономическое положение | sheet=16 | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 2059, duration: 60s
# result saved to ./dataset\Cоциально-экономическое положение\16\outputs\nvidia-nemotron-3-nano-30b-a3b\2026-02-27_15-57-58.json
# TP=20, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Cоциально-экономическое положение | sheet=16 | z-ai/glm-4.5-air:free
# response content len: 2059, duration: 95s
# result saved to ./dataset\Cоциально-экономическое положение\16\outputs\z-ai-glm-4.5-air\2026-02-27_15-59-34.json
# TP=20, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Cоциально-экономическое положение | sheet=16 | arcee-ai/trinity-large-preview:free
# response content len: 1705, duration: 25s
# result saved to ./dataset\Cоциально-экономическое положение\16\outputs\arcee-ai-trinity-large-preview\2026-02-27_15-59-59.json
# TP=20, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Численность не занятых | sheet=Sheet1 | stepfun/step-3.5-flash:free
# response content len: 28671, duration: 170s
# result saved to ./dataset\Численность не занятых\Sheet1\outputs\stepfun-step-3.5-flash\2026-02-27_16-02-50.json
# TP=288, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Численность не занятых | sheet=Sheet1 | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 6966, duration: 70s
# result saved to ./dataset\Численность не занятых\Sheet1\outputs\nvidia-nemotron-3-nano-30b-a3b\2026-02-27_16-04-00.json
# TP=96, FP=0, FN=192, precision=1.0, recall=0.3333, f1=0.5
#
# Численность не занятых | sheet=Sheet1 | z-ai/glm-4.5-air:free
# response content len: 28639, duration: 1405s
# result saved to ./dataset\Численность не занятых\Sheet1\outputs\z-ai-glm-4.5-air\2026-02-27_16-27-26.json
# TP=288, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Численность не занятых | sheet=Sheet1 | arcee-ai/trinity-large-preview:free
# response content len: 11470, duration: 186s
# result saved to ./dataset\Численность не занятых\Sheet1\outputs\arcee-ai-trinity-large-preview\2026-02-27_16-30-33.json
# TP=96, FP=0, FN=192, precision=1.0, recall=0.3333, f1=0.5
#
# Число родившихся | sheet=t1_2 | stepfun/step-3.5-flash:free
# response content len: 8082, duration: 40s
# result saved to ./dataset\Число родившихся\t1_2\outputs\stepfun-step-3.5-flash\2026-02-27_16-31-13.json
# TP=93, FP=3, FN=99, precision=0.9688, recall=0.4844, f1=0.6458
#
# Число родившихся | sheet=t1_2 | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 6054, duration: 60s
# result saved to ./dataset\Число родившихся\t1_2\outputs\nvidia-nemotron-3-nano-30b-a3b\2026-02-27_16-32-14.json
# TP=94, FP=2, FN=98, precision=0.9792, recall=0.4896, f1=0.6528
#
# Число родившихся | sheet=t1_2 | z-ai/glm-4.5-air:free
# response content len: 16151, duration: 768s
# result saved to ./dataset\Число родившихся\t1_2\outputs\z-ai-glm-4.5-air\2026-02-27_16-45-02.json
# TP=192, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Число родившихся | sheet=t1_2 | arcee-ai/trinity-large-preview:free
# response content len: 8070, duration: 145s
# result saved to ./dataset\Число родившихся\t1_2\outputs\arcee-ai-trinity-large-preview\2026-02-27_16-47-27.json
# TP=96, FP=0, FN=96, precision=1.0, recall=0.5, f1=0.6667

# %% [markdown]
# ### HuggingFace

# %%
hf_models = [
    "Qwen/Qwen3-Coder-Next:novita",
    # "google/gemma-3-27b-it:featherless-ai",
    # "XiaomiMiMo/MiMo-V2-Flash:novita"
]

# %%
for model in hf_models:
    for indicator in indicators:
        for sheet in indicator["sheets"]:
            call_llm_save_result_and_validate(
                base_url="https://router.huggingface.co/v1",
                api_key=hf_token,
                model=model,
                indicator=indicator,
                sheet=sheet
            )
# Out:
# Реальная заработная плата | sheet=Данные | Qwen/Qwen3-Coder-Next:novita
# response content len: 391, duration: 3s
# result saved to ./dataset\Реальная заработная плата\Данные\outputs\Qwen-Qwen3-Coder-Next\2026-02-27_17-28-37.json
# TP=4, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ожидаемая продолжительность жизни | sheet=Данные | Qwen/Qwen3-Coder-Next:novita
# response content len: 2199, duration: 7s
# result saved to ./dataset\Ожидаемая продолжительность жизни\Данные\outputs\Qwen-Qwen3-Coder-Next\2026-02-27_17-28-44.json
# TP=13, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Уровень зарегистрированной безработицы | sheet=Sheet1 | Qwen/Qwen3-Coder-Next:novita
# response content len: 28628, duration: 74s
# result saved to ./dataset\Уровень зарегистрированной безработицы\Sheet1\outputs\Qwen-Qwen3-Coder-Next\2026-02-27_17-29-59.json
# TP=288, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Средний возраст | sheet=1.11. | Qwen/Qwen3-Coder-Next:novita
# response content len: 6654, duration: 20s
# result saved to ./dataset\Средний возраст\1.11.\outputs\Qwen-Qwen3-Coder-Next\2026-02-27_17-30-19.json
# TP=96, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Ввод жилых домов | sheet=сентябрь2025 | Qwen/Qwen3-Coder-Next:novita
# response content len: 9845, duration: 28s
# result saved to ./dataset\Ввод жилых домов\сентябрь2025\outputs\Qwen-Qwen3-Coder-Next\2026-02-27_17-30-47.json
# TP=96, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Cоциально-экономическое положение | sheet=16 | Qwen/Qwen3-Coder-Next:novita
# response content len: 1519, duration: 5s
# result saved to ./dataset\Cоциально-экономическое положение\16\outputs\Qwen-Qwen3-Coder-Next\2026-02-27_17-30-53.json
# TP=20, FP=0, FN=0, precision=1.0, recall=1.0, f1=1.0
#
# Численность не занятых | sheet=Sheet1 | Qwen/Qwen3-Coder-Next:novita
# response content len: 9570, duration: 34s
# result saved to ./dataset\Численность не занятых\Sheet1\outputs\Qwen-Qwen3-Coder-Next\2026-02-27_17-31-27.json
# TP=96, FP=0, FN=192, precision=1.0, recall=0.3333, f1=0.5
#
# Число родившихся | sheet=t1_2 | Qwen/Qwen3-Coder-Next:novita
# response content len: 8082, duration: 23s
# result saved to ./dataset\Число родившихся\t1_2\outputs\Qwen-Qwen3-Coder-Next\2026-02-27_17-31-51.json
# TP=96, FP=0, FN=96, precision=1.0, recall=0.5, f1=0.6667

# %% [markdown]
# ### Метрики

# %%
def load_json(path: Path) -> List[dict]:
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

# %%
def get_latest_json_file(model_dir: Path) -> Path:
    """
    Возвращает самый новый JSON файл в папке модели.
    Имя файла уже содержит дату → можно просто взять max().
    """
    json_files = list(model_dir.glob("*.json"))
    if not json_files:
        return None
    return max(json_files)  # по имени (дата в формате YYYY-MM-DD_HH-MM-SS)

# %%
def to_record_dict(data: list, key_fields: list):
    """
    Преобразует список объектов в словарь:
    (dynamic key) -> value

    key_fields: например
        ["subject", "year"]
        ["subject", "year", "month"]
        ["subject", "year", "month", "day"]
    """
    records = {}

    for item in data:
        try:
            key = tuple(item.get(field) for field in key_fields)
        except KeyError as e:
            raise ValueError(f"Missing key field {e} in item {item}")

        records[key] = item["value"]

    return records

# %%
def _to_float(value):
    if value is None:
        return None

    if isinstance(value, (int, float)):
        return float(value)

    if isinstance(value, str):
        value = value.strip().replace(",", ".")
        try:
            return float(value)
        except ValueError:
            return None

    return None

# %%
def compute_metrics(expected: Dict, predicted: Dict):
    expected_keys = set(expected.keys())
    predicted_keys = set(predicted.keys())

    tp_keys = expected_keys & predicted_keys
    fp_keys = predicted_keys - expected_keys
    fn_keys = expected_keys - predicted_keys

    TP = len(tp_keys)
    FP = len(fp_keys)
    FN = len(fn_keys)

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = (
        2 * precision * recall / (precision + recall)
        if (precision + recall) > 0
        else 0
    )

    # === Value metrics ===
    valid_tp_keys = set()
    abs_errors = []
    exact_matches = 0
    
    for key in tp_keys:
        true_val = expected[key]
        pred_val_raw = predicted[key]

        pred_val = _to_float(pred_val_raw)
    
        if pred_val is None:
            # считаем как отсутствие значения → не включаем в TP для value-метрик
            continue
    
        valid_tp_keys.add(key)
    
        if true_val == pred_val:
            exact_matches += 1
    
        abs_errors.append(abs(true_val - pred_val))
    
    # пересчитываем TP для value-метрик
    TP_values = len(valid_tp_keys)
    
    value_accuracy = exact_matches / TP_values if TP_values > 0 else 0
    mae = sum(abs_errors) / len(abs_errors) if abs_errors else 0
    rmse = (
        math.sqrt(sum((e ** 2 for e in abs_errors)) / len(abs_errors))
        if abs_errors
        else 0
    )

    return {
        "TP": TP,
        "FP": FP,
        "FN": FN,
        "precision": round(precision, 4),
        "recall": round(recall, 4),
        "f1": round(f1, 4),
        # opt
        "value_accuracy": round(value_accuracy, 4),
        "mae": round(mae, 6),
        "rmse": round(rmse, 6),
    }

# %%
def evaluate(base_path: Path, target_models: list, indicators: list):
    results = []

    for indicator in indicators:
        indicator_name = indicator["name"]
        sheets = indicator["sheets"]
        key_fields = indicator["key_fields"]

        indicator_path = base_path / indicator_name
        if not indicator_path.exists():
            continue

        for sheet in sheets:
            sheet_name = str(sheet)
            sheet_path = indicator_path / sheet_name

            expected_path = sheet_path / "expected.json"
            outputs_path = sheet_path / "outputs"

            if not expected_path.exists() or not outputs_path.exists():
                continue

            try:
                expected_data = load_json(expected_path)
                expected_records = to_record_dict(expected_data, key_fields)
            except Exception as e:
                print(f"[ERROR] Failed to load expected: {expected_path}: {e}")
                continue

            for model_name in target_models:
                # print(f"Evaluating {indicator_name} | {sheet} | {model_name}\n")
                model_dir = outputs_path / model_name

                if not model_dir.exists():
                    continue

                latest_file = get_latest_json_file(model_dir)
                if not latest_file:
                    continue

                try:
                    predicted_data = load_json(latest_file)
                    predicted_records = to_record_dict(predicted_data, key_fields)
                except Exception as e:
                    print(f"[ERROR] Failed to load prediction: {latest_file}: {e}")
                    continue

                metrics = compute_metrics(expected_records, predicted_records)

                results.append({
                    "indicator": indicator_name,
                    "sheet": sheet_name,
                    "model": model_name,
                    **metrics
                })

    return results

# %%
def aggregate_by_model(results):
    aggregated = defaultdict(lambda: {
        "TP": 0,
        "FP": 0,
        "FN": 0,
        "f1_list": [],
        "value_accuracy_list": [],
        "mae_list": [],
        "rmse_list": []
    })

    for r in results:
        model = r["model"]

        aggregated[model]["TP"] += r["TP"]
        aggregated[model]["FP"] += r["FP"]
        aggregated[model]["FN"] += r["FN"]

        aggregated[model]["f1_list"].append(r["f1"])
        aggregated[model]["value_accuracy_list"].append(r["value_accuracy"])
        aggregated[model]["mae_list"].append(r["mae"])
        aggregated[model]["rmse_list"].append(r["rmse"])

    final_scores = {}

    for model, data in aggregated.items():
        TP = data["TP"]
        FP = data["FP"]
        FN = data["FN"]

        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        recall = TP / (TP + FN) if (TP + FN) > 0 else 0
        micro_f1 = (
            2 * precision * recall / (precision + recall)
            if (precision + recall) > 0
            else 0
        )

        final_scores[model] = {
            # micro metrics
            "micro_precision": round(precision, 4),
            "micro_recall": round(recall, 4),
            "micro_f1": round(micro_f1, 4),

            # macro metrics
            "macro_f1": round(sum(data["f1_list"]) / len(data["f1_list"]), 4),
            "macro_value_accuracy": round(sum(data["value_accuracy_list"]) / len(data["value_accuracy_list"]), 4),

            # средние ошибки
            "avg_mae": round(sum(data["mae_list"]) / len(data["mae_list"]), 6),
            "avg_rmse": round(sum(data["rmse_list"]) / len(data["rmse_list"]), 6),
        }

    return final_scores

# %%
base_path = Path("dataset")

target_models = [
    "Qwen-Qwen3-Coder-Next",
    "stepfun-step-3.5-flash",
    "nvidia-nemotron-3-nano-30b-a3b",
    "z-ai-glm-4.5-air",
    "arcee-ai-trinity-large-preview",
]

# %%
all_results = evaluate(base_path, target_models, indicators)

for result in all_results:    
    print(f"Источник: {result['indicator']}, Лист: {result['sheet']}, Модель: {result['model']}")
    
    table = [[
        result['TP'],
        result['FP'],
        result['FN'],
        round(result['precision'], 3),
        round(result['recall'], 3),
        round(result['f1'], 3),
        round(result['value_accuracy'], 3),
        round(result['mae'], 3),
        round(result['rmse'], 3),
    ]]

    print(
        tabulate(
            table,
            headers=[
                "TP", "FP", "FN",
                "Precision", "Recall", "F1",
                "Value Acc", "MAE", "RMSE"
            ],
            tablefmt="grid"
        )
    )
    print()
# Out:
# Источник: ВВП, Лист: 4, Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    6 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: ВВП, Лист: 4, Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    6 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: ВВП, Лист: 4, Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    6 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: ВВП, Лист: 4, Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    6 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: ВВП, Лист: 4, Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    6 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Реальная заработная плата, Лист: Данные, Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    4 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Реальная заработная плата, Лист: Данные, Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    4 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Реальная заработная плата, Лист: Данные, Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    4 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Реальная заработная плата, Лист: Данные, Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    4 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Реальная заработная плата, Лист: Данные, Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |    4 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ожидаемая продолжительность жизни, Лист: Данные, Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   13 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ожидаемая продолжительность жизни, Лист: Данные, Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   13 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ожидаемая продолжительность жизни, Лист: Данные, Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   13 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ожидаемая продолжительность жизни, Лист: Данные, Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   13 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ожидаемая продолжительность жизни, Лист: Данные, Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   13 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Уровень зарегистрированной безработицы, Лист: Sheet1, Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |  288 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Уровень зарегистрированной безработицы, Лист: Sheet1, Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |  288 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Уровень зарегистрированной безработицы, Лист: Sheet1, Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |  282 |    0 |    6 |           1 |    0.979 | 0.99 |       0.993 | 0.001 |  0.008 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Уровень зарегистрированной безработицы, Лист: Sheet1, Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |  288 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Уровень зарегистрированной безработицы, Лист: Sheet1, Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |    F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+=======+=============+=======+========+
# |  282 |    6 |    6 |       0.979 |    0.979 | 0.979 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
#
# Источник: Средний возраст, Лист: 1.11., Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Средний возраст, Лист: 1.11., Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Средний возраст, Лист: 1.11., Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   95 |    1 |    1 |        0.99 |     0.99 | 0.99 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Средний возраст, Лист: 1.11., Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Средний возраст, Лист: 1.11., Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ввод жилых домов, Лист: сентябрь2025, Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ввод жилых домов, Лист: сентябрь2025, Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ввод жилых домов, Лист: сентябрь2025, Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+-------+-------------+---------+---------+
# |   TP |   FP |   FN |   Precision |   Recall |    F1 |   Value Acc |     MAE |    RMSE |
# +======+======+======+=============+==========+=======+=============+=========+=========+
# |   96 |    1 |    0 |        0.99 |        1 | 0.995 |           0 | 2337.17 | 8551.81 |
# +------+------+------+-------------+----------+-------+-------------+---------+---------+
#
# Источник: Ввод жилых домов, Лист: сентябрь2025, Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Ввод жилых домов, Лист: сентябрь2025, Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+------+-------------+---------+---------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |     MAE |    RMSE |
# +======+======+======+=============+==========+======+=============+=========+=========+
# |   96 |    0 |    0 |           1 |        1 |    1 |           0 | 2134.91 | 7565.71 |
# +------+------+------+-------------+----------+------+-------------+---------+---------+
#
# Источник: Cоциально-экономическое положение, Лист: 16, Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   20 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Cоциально-экономическое положение, Лист: 16, Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   20 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Cоциально-экономическое положение, Лист: 16, Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   20 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Cоциально-экономическое положение, Лист: 16, Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   20 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Cоциально-экономическое положение, Лист: 16, Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   20 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Численность не занятых, Лист: Sheet1, Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |  192 |           1 |    0.333 |  0.5 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Численность не занятых, Лист: Sheet1, Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |  288 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Численность не занятых, Лист: Sheet1, Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |  192 |           1 |    0.333 |  0.5 |       0.083 | 2.189 |  7.794 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Численность не занятых, Лист: Sheet1, Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |  288 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Численность не занятых, Лист: Sheet1, Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |   96 |    0 |  192 |           1 |    0.333 |  0.5 |           0 | 4.633 | 16.344 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Число родившихся, Лист: t1_2, Модель: Qwen-Qwen3-Coder-Next
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |    F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+=======+=============+=======+========+
# |   96 |    0 |   96 |           1 |      0.5 | 0.667 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
#
# Источник: Число родившихся, Лист: t1_2, Модель: stepfun-step-3.5-flash
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |    F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+=======+=============+=======+========+
# |   93 |    3 |   99 |       0.969 |    0.484 | 0.646 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
#
# Источник: Число родившихся, Лист: t1_2, Модель: nvidia-nemotron-3-nano-30b-a3b
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |    F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+=======+=============+=======+========+
# |   94 |    2 |   98 |       0.979 |     0.49 | 0.653 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
#
# Источник: Число родившихся, Лист: t1_2, Модель: z-ai-glm-4.5-air
# +------+------+------+-------------+----------+------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |   F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+======+=============+=======+========+
# |  192 |    0 |    0 |           1 |        1 |    1 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+------+-------------+-------+--------+
#
# Источник: Число родившихся, Лист: t1_2, Модель: arcee-ai-trinity-large-preview
# +------+------+------+-------------+----------+-------+-------------+-------+--------+
# |   TP |   FP |   FN |   Precision |   Recall |    F1 |   Value Acc |   MAE |   RMSE |
# +======+======+======+=============+==========+=======+=============+=======+========+
# |   96 |    0 |   96 |           1 |      0.5 | 0.667 |           1 |     0 |      0 |
# +------+------+------+-------------+----------+-------+-------------+-------+--------+

# %%
model_scores = aggregate_by_model(all_results)


for model, metrics in model_scores.items():
    print(f"MODEL: {model}")

    rows = [[
        metrics.get("micro_precision"),
        metrics.get("micro_recall"),
        metrics.get("micro_f1"),
        metrics.get("macro_value_accuracy"),
        metrics.get("avg_mae"),
        metrics.get("avg_rmse"),
    ]]

    headers = [
        "Micro Precision",
        "Micro Recall",
        "Micro F1",
        "Macro Value Accuracy",
        "MAE",
        "RMSE",
    ]

    print(tabulate(rows, headers=headers, tablefmt="grid"))
    print()
# Out:
# MODEL: Qwen-Qwen3-Coder-Next
# +-------------------+----------------+------------+------------------------+-------+--------+
# |   Micro Precision |   Micro Recall |   Micro F1 |   Macro Value Accuracy |   MAE |   RMSE |
# +===================+================+============+========================+=======+========+
# |                 1 |         0.7129 |     0.8324 |                      1 |     0 |      0 |
# +-------------------+----------------+------------+------------------------+-------+--------+
#
# MODEL: stepfun-step-3.5-flash
# +-------------------+----------------+------------+------------------------+-------+--------+
# |   Micro Precision |   Micro Recall |   Micro F1 |   Macro Value Accuracy |   MAE |   RMSE |
# +===================+================+============+========================+=======+========+
# |            0.9967 |         0.9013 |     0.9466 |                      1 |     0 |      0 |
# +-------------------+----------------+------------+------------------------+-------+--------+
#
# MODEL: nvidia-nemotron-3-nano-30b-a3b
# +-------------------+----------------+------------+------------------------+---------+---------+
# |   Micro Precision |   Micro Recall |   Micro F1 |   Macro Value Accuracy |     MAE |    RMSE |
# +===================+================+============+========================+=========+=========+
# |            0.9944 |         0.7039 |     0.8243 |                 0.7862 | 259.929 | 951.068 |
# +-------------------+----------------+------------+------------------------+---------+---------+
#
# MODEL: z-ai-glm-4.5-air
# +-------------------+----------------+------------+------------------------+-------+--------+
# |   Micro Precision |   Micro Recall |   Micro F1 |   Macro Value Accuracy |   MAE |   RMSE |
# +===================+================+============+========================+=======+========+
# |                 1 |              1 |          1 |                      1 |     0 |      0 |
# +-------------------+----------------+------------+------------------------+-------+--------+
#
# MODEL: arcee-ai-trinity-large-preview
# +-------------------+----------------+------------+------------------------+---------+--------+
# |   Micro Precision |   Micro Recall |   Micro F1 |   Macro Value Accuracy |     MAE |   RMSE |
# +===================+================+============+========================+=========+========+
# |            0.9916 |         0.7069 |     0.8254 |                 0.7778 | 237.727 | 842.45 |
# +-------------------+----------------+------------+------------------------+---------+--------+

# %% [markdown]
# ### Детальный просмотр несоответствий

# %%
for indicator in indicators:
    indicator_name = indicator["name"]
    sheets = indicator["sheets"]
    key_fields = indicator["key_fields"]

    indicator_path = base_path / indicator_name
    if not indicator_path.exists():
        continue

    for sheet in sheets:
        sheet_name = str(sheet)
        sheet_path = indicator_path / sheet_name

        expected_path = sheet_path / "expected.json"
        outputs_path = sheet_path / "outputs"

        if not expected_path.exists() or not outputs_path.exists():
            continue

        try:
            expected_data = load_json(expected_path)
            expected_records = to_record_dict(expected_data, key_fields)
        except Exception as e:
            print(f"[ERROR] Failed to load expected: {expected_path}: {e}")
            continue

        for model_name in target_models:
            model_dir = outputs_path / model_name

            if not model_dir.exists():
                continue

            latest_file = get_latest_json_file(model_dir)
            if not latest_file:
                continue

            try:
                predicted_data = load_json(latest_file)
                predicted_records = to_record_dict(predicted_data, key_fields)
            except Exception as e:
                print(f"[ERROR] Failed to load prediction: {latest_file}: {e}")
                continue

            metrics = compute_basic_metrics(expected_records, predicted_records)
            
            not_matching_values = []
            for key in metrics["TP_KEYS"]:
                true_val = expected_records[key]
                pred_val = predicted_records[key]
                if true_val != pred_val:
                    not_matching_values.append([key, pred_val, true_val])
            
            print(f"{indicator_name} | {sheet} | {model_name}\n")
            print("Количество")
            print(f"- пропущенных ключей {metrics['FN']}")
            print(f"- лишних ключей {metrics['FP']}")
            print(f"- несовпадающих значений {len(not_matching_values)}\n")

            if (len(metrics["FN_KEYS"]) > 0):
                print("Пропущенные ключи:")
                for key in metrics["FN_KEYS"]:
                    print(key)
                print()

            if (len(metrics["FP_KEYS"]) > 0):
                print("Лишние ключи:")
                for key in metrics["FP_KEYS"]:
                    print(key)
                print()
            
            if len(not_matching_values) > 0:
                print("Несовпадающие значения:")
                print(
                    tabulate(
                        not_matching_values,
                        headers=["Key", "Pred", "True"],
                        tablefmt="grid"
                    )
                )
                print()
                
            print("--------------------------------------------------\n")
# Out:
# ВВП | 4 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 4 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 4 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 4 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 4 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Реальная заработная плата | Данные | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Реальная заработная плата | Данные | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Реальная заработная плата | Данные | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Реальная заработная плата | Данные | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Реальная заработная плата | Данные | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Ожидаемая продолжительность жизни | Данные | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Ожидаемая продолжительность жизни | Данные | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Ожидаемая продолжительность жизни | Данные | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Ожидаемая продолжительность жизни | Данные | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Ожидаемая продолжительность жизни | Данные | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Уровень зарегистрированной безработицы | Sheet1 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Уровень зарегистрированной безработицы | Sheet1 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Уровень зарегистрированной безработицы | Sheet1 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 6
# - лишних ключей 0
# - несовпадающих значений 2
#
# Пропущенные ключи:
# ('Тамбовская область', 2024, 7)
# ('Тамбовская область', 2025, 6)
# ('Тверская область', 2024, 7)
# ('Тверская область', 2025, 7)
# ('Тамбовская область', 2025, 7)
# ('Тверская область', 2025, 6)
#
# Несовпадающие значения:
# +-----------------------------+--------+--------+
# | Key                         |   Pred |   True |
# +=============================+========+========+
# | ('г. Севастополь', 2024, 7) |    0.2 |    0.1 |
# +-----------------------------+--------+--------+
# | ('г. Севастополь', 2025, 7) |    0.1 |    0.2 |
# +-----------------------------+--------+--------+
#
# --------------------------------------------------
#
# Уровень зарегистрированной безработицы | Sheet1 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Уровень зарегистрированной безработицы | Sheet1 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 6
# - лишних ключей 6
# - несовпадающих значений 282
#
# Пропущенные ключи:
# ('в том числе: Ненецкий авт. округ', 2024, 7)
# ('в том числе: Ненецкий авт. округ', 2025, 7)
# ('в том числе: Ханты-Мансийский авт. округ - Югра', 2024, 7)
# ('в том числе: Ненецкий авт. округ', 2025, 6)
# ('в том числе: Ханты-Мансийский авт. округ - Югра', 2025, 7)
# ('в том числе: Ханты-Мансийский авт. округ - Югра', 2025, 6)
#
# Лишние ключи:
# ('Ненецкий авт. округ', 2024, 7)
# ('Ханты-Мансийский авт. округ - Югра', 2024, 7)
# ('Ненецкий авт. округ', 2025, 7)
# ('Ханты-Мансийский авт. округ - Югра', 2025, 7)
# ('Ненецкий авт. округ', 2025, 6)
# ('Ханты-Мансийский авт. округ - Югра', 2025, 6)
#
# Несовпадающие значения:
# +----------------------------------------------------+--------+--------+
# | Key                                                | Pred   |   True |
# +====================================================+========+========+
# | ('Краснодарский край', 2025, 6)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Тыва', 2025, 6)                       | 2,6    |    2.6 |
# +----------------------------------------------------+--------+--------+
# | ('Красноярский край', 2024, 7)                     | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Северо-Западный федеральный округ', 2025, 7)     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Северо-Кавказский федеральный округ', 2025, 6)   | 1,2    |    1.2 |
# +----------------------------------------------------+--------+--------+
# | ('Архангельская область', 2025, 7)                 | 1,0    |    1   |
# +----------------------------------------------------+--------+--------+
# | ('Кабардино-Балкарская Республика', 2025, 6)       | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Коми', 2025, 6)                       | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Краснодарский край', 2024, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Саратовская область', 2025, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Курганская область', 2024, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Калининградская область', 2025, 7)               | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Курганская область', 2025, 6)                    | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Алтайский край', 2025, 6)                        | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Дагестан', 2024, 7)                   | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Бурятия', 2024, 7)                    | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Волгоградская область', 2025, 6)                 | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Тюменская область без авт. округов', 2025, 7)    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Ярославская область', 2025, 6)                   | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Ставропольский край', 2025, 6)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Дальневосточный федеральный округ', 2025, 6)     | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Сахалинская область', 2025, 6)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Удмуртская Республика', 2025, 6)                 | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Псковская область', 2025, 6)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('г. Санкт-Петербург', 2025, 6)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Владимирская область', 2024, 7)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Сибирский федеральный округ', 2025, 6)           | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Тверская область', 2025, 7)                      | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Приволжский федеральный округ', 2025, 6)         | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Марий Эл', 2025, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('г. Москва', 2025, 7)                             | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Тамбовская область', 2025, 7)                    | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Северная Осетия - Алания', 2025, 6)   | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Белгородская область', 2025, 7)                  | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Татарстан', 2024, 7)                  | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Омская область', 2025, 6)                        | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Ивановская область', 2025, 6)                    | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Костромская область', 2025, 6)                   | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('г. Санкт-Петербург', 2024, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Астраханская область', 2024, 7)                  | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Приморский край', 2025, 7)                       | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Калужская область', 2024, 7)                     | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Красноярский край', 2025, 7)                     | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Калужская область', 2025, 6)                     | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Мордовия', 2025, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Оренбургская область', 2024, 7)                  | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Приволжский федеральный округ', 2024, 7)         | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Бурятия', 2025, 7)                    | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Хакасия', 2025, 7)                    | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Московская область', 2024, 7)                    | 0,1    |    0.1 |
# +----------------------------------------------------+--------+--------+
# | ('Орловская область', 2024, 7)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Орловская область', 2025, 6)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Калмыкия', 2025, 7)                   | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Ямало-Ненецкий авт. округ', 2025, 6)             | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Магаданская область', 2025, 6)                   | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Курская область', 2025, 6)                       | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Камчатский край', 2024, 7)                       | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Хабаровский край', 2025, 7)                      | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Пензенская область', 2025, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Новгородская область', 2025, 6)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Российская Федерация', 2024, 7)                  | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Мурманская область', 2025, 7)                    | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Российская Федерация', 2025, 6)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Крым', 2025, 6)                       | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Рязанская область', 2025, 7)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Чеченская Республика', 2025, 7)                  | 3,8    |    3.8 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Башкортостан', 2025, 7)               | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Ленинградская область', 2025, 7)                 | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Новосибирская область', 2025, 6)                 | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Чукотский авт. округ', 2024, 7)                  | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Иркутская область', 2025, 6)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Владимирская область', 2025, 7)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Уральский федеральный округ', 2025, 6)           | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Татарстан', 2025, 7)                  | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Новгородская область', 2024, 7)                  | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Московская область', 2025, 7)                    | 0,1    |    0.1 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Крым', 2024, 7)                       | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Вологодская область', 2025, 7)                   | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Пермский край', 2025, 7)                         | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Адыгея', 2025, 7)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Уральский федеральный округ', 2024, 7)           | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Липецкая область', 2025, 7)                      | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Еврейская авт. область', 2024, 7)                | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Кабардино-Балкарская Республика', 2024, 7)       | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Алтай', 2024, 7)                      | 2,1    |    2.1 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Алтай', 2025, 6)                      | 1,8    |    1.8 |
# +----------------------------------------------------+--------+--------+
# | ('Томская область', 2025, 6)                       | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('г. Севастополь', 2025, 6)                        | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Воронежская область', 2025, 7)                   | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Ростовская область', 2025, 6)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Кировская область', 2024, 7)                     | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Карачаево-Черкесская Республика', 2025, 7)       | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Амурская область', 2025, 7)                      | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Чукотский авт. округ', 2025, 7)                  | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Тыва', 2024, 7)                       | 3,4    |    3.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Карелия', 2025, 7)                    | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Томская область', 2024, 7)                       | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Северо-Кавказский федеральный округ', 2024, 7)   | 1,9    |    1.9 |
# +----------------------------------------------------+--------+--------+
# | ('Брянская область', 2025, 7)                      | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Архангельская область', 2025, 6)                 | 0,9    |    0.9 |
# +----------------------------------------------------+--------+--------+
# | ('Ставропольский край', 2024, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Астраханская область', 2025, 6)                  | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Забайкальский край', 2025, 7)                    | 0,9    |    0.9 |
# +----------------------------------------------------+--------+--------+
# | ('г. Севастополь', 2024, 7)                        | 0,1    |    0.1 |
# +----------------------------------------------------+--------+--------+
# | ('Оренбургская область', 2025, 6)                  | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Смоленская область', 2024, 7)                    | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Саратовская область', 2025, 6)                   | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Смоленская область', 2025, 6)                    | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Ростовская область', 2024, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Ульяновская область', 2025, 7)                   | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Северо-Западный федеральный округ', 2024, 7)     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Свердловская область', 2024, 7)                  | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Чувашская Республика', 2025, 7)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Нижегородская область', 2025, 7)                 | 0,0    |    0   |
# +----------------------------------------------------+--------+--------+
# | ('Свердловская область', 2025, 6)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Тюменская область без авт. округов', 2025, 6)    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Алтайский край', 2024, 7)                        | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Самарская область', 2025, 7)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Кемеровская область', 2024, 7)                   | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Кемеровская область', 2025, 6)                   | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Ивановская область', 2024, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Тыва', 2025, 7)                       | 2,5    |    2.5 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Саха (Якутия)', 2024, 7)              | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Тверская область', 2025, 6)                      | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Тюменская область без авт. округов', 2024, 7)    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Саха (Якутия)', 2025, 6)              | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Белгородская область', 2025, 6)                  | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Коми', 2025, 7)                       | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Челябинская область', 2025, 6)                   | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Ингушетия', 2024, 7)                  | 8,8    |    8.8 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Ингушетия', 2025, 6)                  | 5,8    |    5.8 |
# +----------------------------------------------------+--------+--------+
# | ('Курганская область', 2025, 7)                    | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Приморский край', 2025, 6)                       | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Красноярский край', 2025, 6)                     | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Дагестан', 2025, 7)                   | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Мордовия', 2025, 6)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Тверская область', 2024, 7)                      | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Марий Эл', 2024, 7)                   | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Ярославская область', 2025, 7)                   | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Ставропольский край', 2025, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Сахалинская область', 2025, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Псковская область', 2025, 7)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Тульская область', 2025, 7)                      | 0,1    |    0.1 |
# +----------------------------------------------------+--------+--------+
# | ('Иркутская область', 2024, 7)                     | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Магаданская область', 2024, 7)                   | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Приморский край', 2024, 7)                       | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Архангельская область без авт. округа', 2025, 7) | 1,0    |    1   |
# +----------------------------------------------------+--------+--------+
# | ('Хабаровский край', 2025, 6)                      | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Сибирский федеральный округ', 2025, 7)           | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Мордовия', 2024, 7)                   | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Саха (Якутия)', 2025, 7)              | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Пензенская область', 2025, 6)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Северная Осетия - Алания', 2025, 7)   | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Калмыкия', 2024, 7)                   | 0,9    |    0.9 |
# +----------------------------------------------------+--------+--------+
# | ('Ивановская область', 2025, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Центральный федеральный округ', 2025, 7)         | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Рязанская область', 2025, 6)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Ленинградская область', 2025, 6)                 | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Южный федеральный округ', 2024, 7)               | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Южный федеральный округ', 2025, 6)               | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Кировская область', 2025, 6)                     | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Новосибирская область', 2024, 7)                 | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Калужская область', 2025, 7)                     | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Татарстан', 2025, 6)                  | 0,1    |    0.1 |
# +----------------------------------------------------+--------+--------+
# | ('Тюменская область', 2025, 7)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Орловская область', 2025, 7)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Мурманская область', 2024, 7)                    | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Пермский край', 2025, 6)                         | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Рязанская область', 2024, 7)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Башкортостан', 2024, 7)               | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Ямало-Ненецкий авт. округ', 2025, 7)             | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Ленинградская область', 2024, 7)                 | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Камчатский край', 2025, 6)                       | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Северо-Западный федеральный округ', 2025, 6)     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Волгоградская область', 2024, 7)                 | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Дальневосточный федеральный округ', 2024, 7)     | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Российская Федерация', 2025, 7)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Вологодская область', 2024, 7)                   | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Пермский край', 2024, 7)                         | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Новосибирская область', 2025, 7)                 | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Еврейская авт. область', 2025, 7)                | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Удмуртская Республика', 2024, 7)                 | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Иркутская область', 2025, 7)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Воронежская область', 2025, 6)                   | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Калининградская область', 2024, 7)               | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Адыгея', 2024, 7)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Калининградская область', 2025, 6)               | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Чукотский авт. округ', 2025, 6)                  | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Карелия', 2025, 6)                    | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Краснодарский край', 2025, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Брянская область', 2025, 6)                      | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Воронежская область', 2024, 7)                   | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Костромская область', 2024, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Забайкальский край', 2025, 6)                    | 0,9    |    0.9 |
# +----------------------------------------------------+--------+--------+
# | ('Северо-Кавказский федеральный округ', 2025, 7)   | 1,1    |    1.1 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Марий Эл', 2025, 6)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('г. Москва', 2024, 7)                             | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Тамбовская область', 2024, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Амурская область', 2024, 7)                      | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('г. Москва', 2025, 6)                             | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Белгородская область', 2024, 7)                  | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Тамбовская область', 2025, 6)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Кабардино-Балкарская Республика', 2025, 7)       | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Карелия', 2024, 7)                    | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Чувашская Республика', 2024, 7)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Чувашская Республика', 2025, 6)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('г. Севастополь', 2025, 7)                        | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Самарская область', 2024, 7)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Алтай', 2025, 7)                      | 1,9    |    1.9 |
# +----------------------------------------------------+--------+--------+
# | ('Самарская область', 2025, 6)                     | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Ростовская область', 2025, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Челябинская область', 2024, 7)                   | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Алтайский край', 2025, 7)                        | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Курская область', 2024, 7)                       | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Бурятия', 2025, 6)                    | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Волгоградская область', 2025, 7)                 | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Хакасия', 2024, 7)                    | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Ульяновская область', 2024, 7)                   | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Хакасия', 2025, 6)                    | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Калмыкия', 2025, 6)                   | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Дальневосточный федеральный округ', 2025, 7)     | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Удмуртская Республика', 2025, 7)                 | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('г. Санкт-Петербург', 2025, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Астраханская область', 2025, 7)                  | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Хабаровский край', 2024, 7)                      | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Оренбургская область', 2025, 7)                  | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Приволжский федеральный округ', 2025, 7)         | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Пензенская область', 2024, 7)                    | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Смоленская область', 2025, 7)                    | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Омская область', 2025, 7)                        | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Мурманская область', 2025, 6)                    | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Чеченская Республика', 2025, 6)                  | 3,9    |    3.9 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Дагестан', 2025, 6)                   | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Башкортостан', 2025, 6)               | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Свердловская область', 2025, 7)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Костромская область', 2025, 7)                   | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Кемеровская область', 2025, 7)                   | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Владимирская область', 2025, 6)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Коми', 2024, 7)                       | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Камчатский край', 2025, 7)                       | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Тульская область', 2025, 6)                      | 0,1    |    0.1 |
# +----------------------------------------------------+--------+--------+
# | ('Московская область', 2025, 6)                    | 0,1    |    0.1 |
# +----------------------------------------------------+--------+--------+
# | ('Архангельская область без авт. округа', 2024, 7) | 1,1    |    1.1 |
# +----------------------------------------------------+--------+--------+
# | ('Вологодская область', 2025, 6)                   | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Архангельская область без авт. округа', 2025, 6) | 0,9    |    0.9 |
# +----------------------------------------------------+--------+--------+
# | ('Чеченская Республика', 2024, 7)                  | 6,5    |    6.5 |
# +----------------------------------------------------+--------+--------+
# | ('Магаданская область', 2025, 7)                   | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Ярославская область', 2024, 7)                   | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Сахалинская область', 2024, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Адыгея', 2025, 6)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Челябинская область', 2025, 7)                   | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Курская область', 2025, 7)                       | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Центральный федеральный округ', 2025, 6)         | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Липецкая область', 2024, 7)                      | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Тульская область', 2024, 7)                      | 0,1    |    0.1 |
# +----------------------------------------------------+--------+--------+
# | ('Липецкая область', 2025, 6)                      | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Новгородская область', 2025, 7)                  | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Псковская область', 2024, 7)                     | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Крым', 2025, 7)                       | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Ингушетия', 2025, 7)                  | 5,6    |    5.6 |
# +----------------------------------------------------+--------+--------+
# | ('Сибирский федеральный округ', 2024, 7)           | 0,7    |    0.7 |
# +----------------------------------------------------+--------+--------+
# | ('Тюменская область', 2025, 6)                     | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Республика Северная Осетия - Алания', 2024, 7)   | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Архангельская область', 2024, 7)                 | 1,1    |    1.1 |
# +----------------------------------------------------+--------+--------+
# | ('Центральный федеральный округ', 2024, 7)         | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Уральский федеральный округ', 2025, 7)           | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Саратовская область', 2024, 7)                   | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Карачаево-Черкесская Республика', 2024, 7)       | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Карачаево-Черкесская Республика', 2025, 6)       | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Амурская область', 2025, 6)                      | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Тюменская область', 2024, 7)                     | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Брянская область', 2024, 7)                      | 0,4    |    0.4 |
# +----------------------------------------------------+--------+--------+
# | ('Ульяновская область', 2025, 6)                   | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Ямало-Ненецкий авт. округ', 2024, 7)             | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Южный федеральный округ', 2025, 7)               | 0,3    |    0.3 |
# +----------------------------------------------------+--------+--------+
# | ('Забайкальский край', 2024, 7)                    | 1,1    |    1.1 |
# +----------------------------------------------------+--------+--------+
# | ('Кировская область', 2025, 7)                     | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Еврейская авт. область', 2025, 6)                | 0,6    |    0.6 |
# +----------------------------------------------------+--------+--------+
# | ('Омская область', 2024, 7)                        | 0,8    |    0.8 |
# +----------------------------------------------------+--------+--------+
# | ('Томская область', 2025, 7)                       | 0,5    |    0.5 |
# +----------------------------------------------------+--------+--------+
# | ('Нижегородская область', 2024, 7)                 | 0,2    |    0.2 |
# +----------------------------------------------------+--------+--------+
# | ('Нижегородская область', 2025, 6)                 | 0,0    |    0   |
# +----------------------------------------------------+--------+--------+
#
# --------------------------------------------------
#
# Средний возраст | 1.11. | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Средний возраст | 1.11. | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Средний возраст | 1.11. | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 1
# - лишних ключей 1
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('Кировская область', 2024)
#
# Лишние ключи:
# ('Киевская область', 2024)
#
# --------------------------------------------------
#
# Средний возраст | 1.11. | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Средний возраст | 1.11. | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Ввод жилых домов | сентябрь2025 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Ввод жилых домов | сентябрь2025 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Ввод жилых домов | сентябрь2025 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 1
# - несовпадающих значений 96
#
# ...
# +--------------------------------------------------------------+--------+--------+
# | ('Омская область', 2025, 7)                                  |    6.1 |    8.9 |
# +--------------------------------------------------------------+--------+--------+
# | ('Свердловская область', 2025, 7)                            |    8.2 |   12.2 |
# +--------------------------------------------------------------+--------+--------+
# | ('Костромская область', 2025, 7)                             |    0.5 |    1.1 |
# +--------------------------------------------------------------+--------+--------+
# | ('Кемеровская область', 2025, 7)                             |    6.8 |    9.8 |
# +--------------------------------------------------------------+--------+--------+
# | ('Камчатский край', 2025, 7)                                 |    0.5 |    0.8 |
# +--------------------------------------------------------------+--------+--------+
# | ('Магаданская область', 2025, 7)                             |    0.2 |    0.5 |
# +--------------------------------------------------------------+--------+--------+
# | ('Челябинская область', 2025, 7)                             |    6.2 |    8.8 |
# +--------------------------------------------------------------+--------+--------+
# | ('Курская область', 2025, 7)                                 |    1.2 |    1.6 |
# +--------------------------------------------------------------+--------+--------+
# | ('Республика Ингушетия', 2025, 7)                            |    7.3 |   16.7 |
# +--------------------------------------------------------------+--------+--------+
# | ('Новгородская область', 2025, 7)                            |    1   |    1.4 |
# +--------------------------------------------------------------+--------+--------+
# | ('Республика Крым', 2025, 7)                                 |    3.3 |    4.3 |
# +--------------------------------------------------------------+--------+--------+
# | ('Уральский федеральный округ', 2025, 7)                     |   18.8 |   30.1 |
# +--------------------------------------------------------------+--------+--------+
# | ('Южный федеральный округ', 2025, 7)                         |   22.3 |   32.1 |
# +--------------------------------------------------------------+--------+--------+
# | ('Кировская область', 2025, 7)                               |    1   |    1.7 |
# +--------------------------------------------------------------+--------+--------+
# | ('Томская область', 2025, 7)                                 |    2.4 |    3.6 |
# +--------------------------------------------------------------+--------+--------+
#
# --------------------------------------------------
#
# Число родившихся | t1_2 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 96
# - лишних ключей 0
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('Курганская область', 2024)
# ('Красноярский край', 2024)
# ('Российская Федерация', 2024)
# ('Республика Карелия', 2024)
# ('Алтайский край', 2024)
# ('Кировская область', 2024)
# ('Северо-Кавказский федеральный округ', 2024)
# ('Дальневосточный федеральный округ', 2024)
# ('Оренбургская область', 2024)
# ('Республика Коми', 2024)
# ('Ямало-Hенецкий авт.округ', 2024)
# ('Мурманская область', 2024)
# ('Республика Хакасия', 2024)
# ('Забайкальский край', 2024)
# ('Волгоградская область', 2024)
# ('Республика Татарстан(Татарстан)', 2024)
# ('Хабаровский край', 2024)
# ('Кабардино-Балкарская Республика', 2024)
# ('Тюменская область', 2024)
# ('Кемеровская область', 2024)
# ('Республика Тыва', 2024)
# ('Ставропольский край', 2024)
# ('Республика Башкортостан', 2024)
# ('г.Севастополь', 2024)
# ('Смоленская область', 2024)
# ('Магаданская область', 2024)
# ('Сахалинская область', 2024)
# ('г.Москва', 2024)
# ('Приволжский федеральный округ', 2024)
# ('Уральский федеральный округ', 2024)
# ('Краснодарский край', 2024)
# ('Республика Марий Эл', 2024)
# ('Новосибирская область', 2024)
# ('Омская область', 2024)
# ('Ленинградская область', 2024)
# ('Республика Адыгея', 2024)
# ('Челябинская область', 2024)
# ('Республика Мордовия', 2024)
# ('Еврейская автономная область', 2024)
# ('Камчатский край', 2024)
# ('Южный федеральный округ', 2024)
# ('Псковская область', 2024)
# ('Курская область', 2024)
# ('Ивановская область', 2024)
# ('Карачаево-Черкесская Республика', 2024)
# ('Центральный федеральный округ', 2024)
# ('Ярославская область', 2024)
# ('Самарская область', 2024)
# ('Пензенская область', 2024)
# ('Архангельская область', 2024)
# ('Республика Саха (Якутия)', 2024)
# ('Архангельская область без автономии', 2024)
# ('Астраханская область', 2024)
# ('Республика Бурятия', 2024)
# ('Ханты-Мансийский авт.округ-Югра', 2024)
# ('Владимирская область', 2024)
# ('Орловская область', 2024)
# ('Ульяновская область', 2024)
# ('Республика Алтай', 2024)
# ('Республика Крым', 2024)
# ('Чукотский авт.округ', 2024)
# ('Томская область', 2024)
# ('Вологодская область', 2024)
# ('Саратовская область', 2024)
# ('Тамбовская область', 2024)
# ('Ростовская область', 2024)
# ('Hенецкий авт.округ', 2024)
# ('Hижегородская область', 2024)
# ('Липецкая область', 2024)
# ('Северо-Западный федеральный округ', 2024)
# ('Тюменская область без автономии', 2024)
# ('Тверская область', 2024)
# ('Калужская область', 2024)
# ('Республика Северная Осетия- Алания', 2024)
# ('Сибирский федеральный округ', 2024)
# ('Пермский край', 2024)
# ('Новгородская область', 2024)
# ('Воронежская область', 2024)
# ('Свердловская область', 2024)
# ('Брянская область', 2024)
# ('Рязанская область', 2024)
# ('Чувашская Республика(Чувашия)', 2024)
# ('Костромская область', 2024)
# ('Белгородская область', 2024)
# ('Приморский край', 2024)
# ('Республика Дагестан', 2024)
# ('Республика Ингушетия', 2024)
# ('Республика Калмыкия', 2024)
# ('Иркутская область', 2024)
# ('Чеченская Республика', 2024)
# ('г.Санкт-Петербург', 2024)
# ('Удмуртская Республика', 2024)
# ('Московская область', 2024)
# ('Тульская область', 2024)
# ('Амурская область', 2024)
# ('Калининградская область', 2024)
#
# --------------------------------------------------
#
# Число родившихся | t1_2 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 99
# - лишних ключей 3
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('Курганская область', 2024)
# ('Красноярский край', 2024)
# ('Российская Федерация', 2024)
# ('Республика Карелия', 2024)
# ('Алтайский край', 2024)
# ('Кировская область', 2024)
# ('Северо-Кавказский федеральный округ', 2024)
# ('Дальневосточный федеральный округ', 2024)
# ('Оренбургская область', 2024)
# ('Республика Коми', 2024)
# ('Ямало-Hенецкий авт.округ', 2024)
# ('Мурманская область', 2024)
# ('Республика Хакасия', 2024)
# ('Забайкальский край', 2024)
# ('Hижегородская область', 2025)
# ('Волгоградская область', 2024)
# ('Республика Татарстан(Татарстан)', 2024)
# ('Хабаровский край', 2024)
# ('Кабардино-Балкарская Республика', 2024)
# ('Тюменская область', 2024)
# ('Кемеровская область', 2024)
# ('Республика Тыва', 2024)
# ('Ставропольский край', 2024)
# ('Республика Башкортостан', 2024)
# ('г.Севастополь', 2024)
# ('Смоленская область', 2024)
# ('Магаданская область', 2024)
# ('Сахалинская область', 2024)
# ('г.Москва', 2024)
# ('Приволжский федеральный округ', 2024)
# ('Уральский федеральный округ', 2024)
# ('Краснодарский край', 2024)
# ('Республика Марий Эл', 2024)
# ('Новосибирская область', 2024)
# ('Омская область', 2024)
# ('Ленинградская область', 2024)
# ('Республика Адыгея', 2024)
# ('Челябинская область', 2024)
# ('Республика Мордовия', 2024)
# ('Hенецкий авт.округ', 2025)
# ('Еврейская автономная область', 2024)
# ('Камчатский край', 2024)
# ('Южный федеральный округ', 2024)
# ('Псковская область', 2024)
# ('Курская область', 2024)
# ('Ивановская область', 2024)
# ('Карачаево-Черкесская Республика', 2024)
# ('Центральный федеральный округ', 2024)
# ('Ярославская область', 2024)
# ('Самарская область', 2024)
# ('Пензенская область', 2024)
# ('Ямало-Hенецкий авт.округ', 2025)
# ('Архангельская область', 2024)
# ('Республика Саха (Якутия)', 2024)
# ('Архангельская область без автономии', 2024)
# ('Астраханская область', 2024)
# ('Республика Бурятия', 2024)
# ('Ханты-Мансийский авт.округ-Югра', 2024)
# ('Владимирская область', 2024)
# ('Орловская область', 2024)
# ('Ульяновская область', 2024)
# ('Республика Алтай', 2024)
# ('Республика Крым', 2024)
# ('Чукотский авт.округ', 2024)
# ('Томская область', 2024)
# ('Вологодская область', 2024)
# ('Саратовская область', 2024)
# ('Тамбовская область', 2024)
# ('Ростовская область', 2024)
# ('Hенецкий авт.округ', 2024)
# ('Hижегородская область', 2024)
# ('Липецкая область', 2024)
# ('Северо-Западный федеральный округ', 2024)
# ('Тюменская область без автономии', 2024)
# ('Тверская область', 2024)
# ('Калужская область', 2024)
# ('Республика Северная Осетия- Алания', 2024)
# ('Сибирский федеральный округ', 2024)
# ('Пермский край', 2024)
# ('Новгородская область', 2024)
# ('Воронежская область', 2024)
# ('Свердловская область', 2024)
# ('Брянская область', 2024)
# ('Рязанская область', 2024)
# ('Чувашская Республика(Чувашия)', 2024)
# ('Костромская область', 2024)
# ('Белгородская область', 2024)
# ('Приморский край', 2024)
# ('Республика Дагестан', 2024)
# ('Республика Ингушетия', 2024)
# ('Республика Калмыкия', 2024)
# ('Иркутская область', 2024)
# ('Чеченская Республика', 2024)
# ('г.Санкт-Петербург', 2024)
# ('Удмуртская Республика', 2024)
# ('Московская область', 2024)
# ('Тульская область', 2024)
# ('Амурская область', 2024)
# ('Калининградская область', 2024)
#
# Лишние ключи:
# ('Нижегородская область', 2025)
# ('Ненецкий авт.округ', 2025)
# ('Ямало-Ненецкий авт.округ', 2025)
#
# --------------------------------------------------
#
# Число родившихся | t1_2 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 98
# - лишних ключей 2
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('Курганская область', 2024)
# ('Красноярский край', 2024)
# ('Российская Федерация', 2024)
# ('Республика Карелия', 2024)
# ('Алтайский край', 2024)
# ('Кировская область', 2024)
# ('Северо-Кавказский федеральный округ', 2024)
# ('Дальневосточный федеральный округ', 2024)
# ('Оренбургская область', 2024)
# ('Республика Коми', 2024)
# ('Ямало-Hенецкий авт.округ', 2024)
# ('Мурманская область', 2024)
# ('Республика Хакасия', 2024)
# ('Забайкальский край', 2024)
# ('Hижегородская область', 2025)
# ('Волгоградская область', 2024)
# ('Республика Татарстан(Татарстан)', 2024)
# ('Хабаровский край', 2024)
# ('Кабардино-Балкарская Республика', 2024)
# ('Тюменская область', 2024)
# ('Кемеровская область', 2024)
# ('Республика Тыва', 2024)
# ('Ставропольский край', 2024)
# ('Республика Башкортостан', 2024)
# ('г.Севастополь', 2024)
# ('Смоленская область', 2024)
# ('Магаданская область', 2024)
# ('Сахалинская область', 2024)
# ('г.Москва', 2024)
# ('Приволжский федеральный округ', 2024)
# ('Уральский федеральный округ', 2024)
# ('Краснодарский край', 2024)
# ('Республика Марий Эл', 2024)
# ('Новосибирская область', 2024)
# ('Омская область', 2024)
# ('Ленинградская область', 2024)
# ('Республика Адыгея', 2024)
# ('Челябинская область', 2024)
# ('Республика Мордовия', 2024)
# ('Еврейская автономная область', 2024)
# ('Камчатский край', 2024)
# ('Южный федеральный округ', 2024)
# ('Псковская область', 2024)
# ('Курская область', 2024)
# ('Ивановская область', 2024)
# ('Карачаево-Черкесская Республика', 2024)
# ('Центральный федеральный округ', 2024)
# ('Ярославская область', 2024)
# ('Самарская область', 2024)
# ('Пензенская область', 2024)
# ('Ямало-Hенецкий авт.округ', 2025)
# ('Архангельская область', 2024)
# ('Республика Саха (Якутия)', 2024)
# ('Архангельская область без автономии', 2024)
# ('Астраханская область', 2024)
# ('Республика Бурятия', 2024)
# ('Ханты-Мансийский авт.округ-Югра', 2024)
# ('Владимирская область', 2024)
# ('Орловская область', 2024)
# ('Ульяновская область', 2024)
# ('Республика Алтай', 2024)
# ('Республика Крым', 2024)
# ('Чукотский авт.округ', 2024)
# ('Томская область', 2024)
# ('Вологодская область', 2024)
# ('Саратовская область', 2024)
# ('Тамбовская область', 2024)
# ('Ростовская область', 2024)
# ('Hенецкий авт.округ', 2024)
# ('Hижегородская область', 2024)
# ('Липецкая область', 2024)
# ('Северо-Западный федеральный округ', 2024)
# ('Тюменская область без автономии', 2024)
# ('Тверская область', 2024)
# ('Калужская область', 2024)
# ('Республика Северная Осетия- Алания', 2024)
# ('Сибирский федеральный округ', 2024)
# ('Пермский край', 2024)
# ('Новгородская область', 2024)
# ('Воронежская область', 2024)
# ('Свердловская область', 2024)
# ('Брянская область', 2024)
# ('Рязанская область', 2024)
# ('Чувашская Республика(Чувашия)', 2024)
# ('Костромская область', 2024)
# ('Белгородская область', 2024)
# ('Приморский край', 2024)
# ('Республика Дагестан', 2024)
# ('Республика Ингушетия', 2024)
# ('Республика Калмыкия', 2024)
# ('Иркутская область', 2024)
# ('Чеченская Республика', 2024)
# ('г.Санкт-Петербург', 2024)
# ('Удмуртская Республика', 2024)
# ('Московская область', 2024)
# ('Тульская область', 2024)
# ('Амурская область', 2024)
# ('Калининградская область', 2024)
#
# Лишние ключи:
# ('Нижегородская область', 2025)
# ('Ямало-Ненецкий авт.округ', 2025)
#
# --------------------------------------------------
#
# Число родившихся | t1_2 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Число родившихся | t1_2 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 96
# - лишних ключей 0
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('Курганская область', 2024)
# ('Красноярский край', 2024)
# ('Российская Федерация', 2024)
# ('Республика Карелия', 2024)
# ('Алтайский край', 2024)
# ('Кировская область', 2024)
# ('Северо-Кавказский федеральный округ', 2024)
# ('Дальневосточный федеральный округ', 2024)
# ('Оренбургская область', 2024)
# ('Республика Коми', 2024)
# ('Ямало-Hенецкий авт.округ', 2024)
# ('Мурманская область', 2024)
# ('Республика Хакасия', 2024)
# ('Забайкальский край', 2024)
# ('Волгоградская область', 2024)
# ('Республика Татарстан(Татарстан)', 2024)
# ('Хабаровский край', 2024)
# ('Кабардино-Балкарская Республика', 2024)
# ('Тюменская область', 2024)
# ('Кемеровская область', 2024)
# ('Республика Тыва', 2024)
# ('Ставропольский край', 2024)
# ('Республика Башкортостан', 2024)
# ('г.Севастополь', 2024)
# ('Смоленская область', 2024)
# ('Магаданская область', 2024)
# ('Сахалинская область', 2024)
# ('г.Москва', 2024)
# ('Приволжский федеральный округ', 2024)
# ('Уральский федеральный округ', 2024)
# ('Краснодарский край', 2024)
# ('Республика Марий Эл', 2024)
# ('Новосибирская область', 2024)
# ('Омская область', 2024)
# ('Ленинградская область', 2024)
# ('Республика Адыгея', 2024)
# ('Челябинская область', 2024)
# ('Республика Мордовия', 2024)
# ('Еврейская автономная область', 2024)
# ('Камчатский край', 2024)
# ('Южный федеральный округ', 2024)
# ('Псковская область', 2024)
# ('Курская область', 2024)
# ('Ивановская область', 2024)
# ('Карачаево-Черкесская Республика', 2024)
# ('Центральный федеральный округ', 2024)
# ('Ярославская область', 2024)
# ('Самарская область', 2024)
# ('Пензенская область', 2024)
# ('Архангельская область', 2024)
# ('Республика Саха (Якутия)', 2024)
# ('Архангельская область без автономии', 2024)
# ('Астраханская область', 2024)
# ('Республика Бурятия', 2024)
# ('Ханты-Мансийский авт.округ-Югра', 2024)
# ('Владимирская область', 2024)
# ('Орловская область', 2024)
# ('Ульяновская область', 2024)
# ('Республика Алтай', 2024)
# ('Республика Крым', 2024)
# ('Чукотский авт.округ', 2024)
# ('Томская область', 2024)
# ('Вологодская область', 2024)
# ('Саратовская область', 2024)
# ('Тамбовская область', 2024)
# ('Ростовская область', 2024)
# ('Hенецкий авт.округ', 2024)
# ('Hижегородская область', 2024)
# ('Липецкая область', 2024)
# ('Северо-Западный федеральный округ', 2024)
# ('Тюменская область без автономии', 2024)
# ('Тверская область', 2024)
# ('Калужская область', 2024)
# ('Республика Северная Осетия- Алания', 2024)
# ('Сибирский федеральный округ', 2024)
# ('Пермский край', 2024)
# ('Новгородская область', 2024)
# ('Воронежская область', 2024)
# ('Свердловская область', 2024)
# ('Брянская область', 2024)
# ('Рязанская область', 2024)
# ('Чувашская Республика(Чувашия)', 2024)
# ('Костромская область', 2024)
# ('Белгородская область', 2024)
# ('Приморский край', 2024)
# ('Республика Дагестан', 2024)
# ('Республика Ингушетия', 2024)
# ('Республика Калмыкия', 2024)
# ('Иркутская область', 2024)
# ('Чеченская Республика', 2024)
# ('г.Санкт-Петербург', 2024)
# ('Удмуртская Республика', 2024)
# ('Московская область', 2024)
# ('Тульская область', 2024)
# ('Амурская область', 2024)
# ('Калининградская область', 2024)
#
# --------------------------------------------------

# %% [markdown]
# ## Преобразование в различные форматы

# %%
def save_to_other_formats(sub_directory, ext, sheet_name):
    input_path = Path(f"./dataset/{sub_directory}/input.{ext}")
    try:
        print(f"Processing file: {input_path}, sheet: {sheet_name}")
        
        df = pd.read_excel(input_path, sheet_name=sheet_name)
        df = df.replace("", pd.NA)
        df = df.dropna(how="all")
        df = df.fillna("")
        
        df = df.map(
            lambda x: int(x) if isinstance(x, float) and x.is_integer()
            else round(x, 2) if isinstance(x, (int, float))
            else x
        )
        df = df.map(lambda x: x.replace('\n', ' ') if isinstance(x, str) else x)
        df = df.map(lambda x: " ".join(x.split()) if isinstance(x, str) else x)
        df = df.rename(columns=lambda x: "" if str(x).startswith("Unnamed") else x)
        df = df.map(lambda x: str(x).strip())

        output_dir = Path(f"./dataset/{sub_directory}/{sheet_name}")
        output_dir.mkdir(parents=True, exist_ok=True)
        
        df.to_csv(output_dir / "input.csv", index=False)
        df.to_html(output_dir / "input.html", index=False)
        df.to_markdown(output_dir / "input.md", index=False)

        print(f"Files saved in {output_dir}")
    except Exception as e:
        print(f"Error processing {input_path}: {e}")

# %%
for indicator in indicators:
    for sheet in indicator["sheets"]:
        save_to_other_formats(indicator["name"], "xlsx", sheet)
# Out:
# Processing file: dataset\ВРП\input.xlsx, sheet: 1
# Files saved in dataset\ВРП\1
# Processing file: dataset\ВРП\input.xlsx, sheet: 2
# Files saved in dataset\ВРП\2
# Processing file: dataset\ВРП\input.xlsx, sheet: 3
# Files saved in dataset\ВРП\3
# Processing file: dataset\ВРП\input.xlsx, sheet: 4
# Files saved in dataset\ВРП\4

# %%
save_to_other_formats("ВРП", "xlsx", "12")
# Out:
# Processing file: dataset\ВРП\input.xlsx, sheet: 12
# Files saved in dataset\ВРП\12

# %% [markdown]
# ### Составление expected для больших файлов

# %%
input_csv = "./dataset/ВРП/12/input.csv"
output_json = "./dataset/ВРП/12/expected.json"
years_row_number = 2

results = []

with open(input_csv, newline="", encoding="utf-8") as f:
    reader = csv.reader(f)
    rows = list(reader)

years_row = rows[years_row_number]

years = [y for y in years_row[1:] if y.strip() != ""]

data_rows = rows[years_row_number+1:]

for row in data_rows:
    if not row or row[0].strip() == "":
        continue

    subject = row[0].strip()

    # Пропускаем строки, которые не являются регионами
    # if any(keyword in subject.lower() for keyword in ["округ", "валовой"]):
    #     continue

    values = row[1:]

    for year, value in zip(years, values):
        value = value.strip()
        if value == "":
            continue

        value = float(value.replace(",", ".").replace(" ", ""))

        results.append({
            "subject": subject,
            "year": year,
            "month": None,
            "day": None,
            "value": value
        })

with open(output_json, "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)
    print("Saved!")
# Out:
# Saved!
