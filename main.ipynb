# %%
import json
import math
import csv
import time
import datetime
import pandas as pd
from openai import OpenAI
from huggingface_hub import InferenceClient
from dotenv import load_dotenv
import os
import re
from pathlib import Path
from typing import Dict, Tuple, List
from collections import defaultdict
from tabulate import tabulate
from itertools import zip_longest

# %% [markdown]
# ## Тестирование LLM

# %%
load_dotenv()
hf_token = os.getenv("HF_TOKEN")
or_key = os.getenv("OR_KEY")

# %%
def strip_json_fence(text: str) -> str:
    return re.sub(r"^```(?:json)?\s*|\s*```$", "", text.strip(), flags=re.IGNORECASE)

# %%
def call_llm(base_url, api_key, model, system_message, prompt):
    client = OpenAI(
        base_url=base_url,
        api_key=api_key,
        timeout=1800
    )
    
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt},
        ],
        # temperature=0,
    )
    
    return completion.choices[0].message.content

# %%
def get_differences(model_output, expected_data):
    ref_dict = {(item['subject'], item['year']): item for item in expected_data}
    model_dict = {(item['subject'], item['year']): item for item in model_output}
    
    differences = []
    for key, ref_item in ref_dict.items():
        model_item = model_dict.get(key)
        if model_item is None:
            differences.append(('Ключ отсутствует в результате', key))
        elif model_item != ref_item:
            differences.append(('Есть различия', key, model_item, ref_item))

    return differences

# %%
def save_json_data(directory, data):
    os.makedirs(directory, exist_ok=True)

    filename = os.path.join(
        directory,
        f"{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.json"
    )
    
    with open(filename, 'w', encoding='utf-8') as file:
        json.dump(data, file, ensure_ascii=False, indent=2)
        print(f"result saved to {filename}")

# %%
def call_llm_save_result_and_validate(base_url, api_key, model, indicator_name):
    try:
        print(f"{indicator_name} | {model}")
    
        with open(f"./dataset/{indicator_name}/system.md", "r", encoding="utf-8") as file:
            system_message = file.read()
        
        with open(f"./dataset/{indicator_name}/input.csv", "r", encoding="utf-8") as file:
            data = file.read()
        
        with open(f"./dataset/{indicator_name}/expected.json", "r", encoding="utf-8") as file:
            expected_data = json.loads(file.read())

        start = time.perf_counter()
        content = call_llm(base_url, api_key, model, system_message, data)
        end = time.perf_counter()
        
        print(f"response content len: {len(content)}, duration: {int(end - start)}s")
    
        result = json.loads(strip_json_fence(content))
        
        for item in result:
            if 'month' not in item:
                item['month'] = None
            if 'day' not in item:
                item['day'] = None
        
        # Создаем путь ./save_dir/outputs/<model_name>
        model_name_safe = model.split(":")[0].replace("/", "-")
        directory = os.path.join(f"./dataset/{indicator_name}", "outputs", model_name_safe)
        os.makedirs(directory, exist_ok=True)
        
        save_json_data(directory, result)
    
        differences = get_differences(result, expected_data)
        print(f'{len(differences)} неточностей\n')
    
        return differences
    except Exception as e:
        print(f"Произошла ошибка: {e}\n")

# %%
indicators = [
    # Обучающая выборка
    {
        "name": "ВВП",
        "sheets": [
            1,
            2,
            3,
        ],
        "key_fields": ["subject", "year"]
    },
    {
        "name": "Индекс потребительских цен (за рассматриваемый период)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Индекс производства (оперативные данные)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Непродовольственные товары (за рассматриваемый период)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Непродовольственные товары (к декабрю предыдущего года)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Продовольственные товары (за рассматриваемый период)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Продовольственные товары (к декабрю предыдущего года)",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Численность постоянного населения",
        "sheets": ["Данные"],
        "key_fields": ["subject", "year"]
    },
    {
        "name": "Потребность работодателей",
        "sheets": ["Sheet1"],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Ввод жилых домов",
        "sheets": [
            "июнь 2025",
            "июль2025",
            "август2025"
        ],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Cоциально-экономическое положение",
        "sheets": [
            "8",
            "11",
            "12"
        ],
        "key_fields": ["subject", "year", "month"]
    },
    {
        "name": "Численность и состав рабочей силы",
        "sheets": ["Sheet1"],
        "key_fields": ["subject", "year"]
    },

    # Тестовая выборка
    # {
    #     "name": "ВВП",
    #     "sheets": [4],
    # },
    # {
    #     "name": "Реальная заработная плата",
    #     "sheets": ["Данные"],
    # },
    # {
    #     "name": "Ожидаемая продолжительность жизни",
    #     "sheets": ["Данные"],
    # },
    # {
    #     "name": "Уровень зарегистрированной безработицы",
    #     "sheets": ["Sheet1"],
    # },
    # {
    #     "name": "Средний возраст",
    #     "sheets": ["1.11."],
    # },
    # {
    #     "name": "Ввод жилых домов,
    #     "sheets": [
    #         "сентябрь2025",
    #     ],
    # },
    # {
    #     "name": "Cоциально-экономическое положение,
    #     "sheets": [
    #         "16"
    #     ],
    # },
    # {
    #     "name": "Численность не занятых",
    #     "sheets": ["Sheet1"],
    # },
    # {
    #     "name": "Число родившихся",
    #     "sheets": ["t1_2"],
    # },
]

# %% [markdown]
# ### OpenRouter

# %%
or_models = [
    # "qwen/qwen3-next-80b-a3b-instruct:free", # rate-limited
    # "qwen/qwen3-coder:free", # rate-limited
    "stepfun/step-3.5-flash:free",
    "nvidia/nemotron-3-nano-30b-a3b:free",
    "z-ai/glm-4.5-air:free",
    # "google/gemma-3-27b-it:free", # rate-limited
    "arcee-ai/trinity-large-preview:free",
    # "openrouter/aurora-alpha", # закончился тестовый период
    # "mistralai/mistral-small-3.1-24b-instruct:free", # rate-limited
    # "openrouter/pony-alpha", # 404
    # "openai/gpt-oss-120b:free", # 404
    # "openai/gpt-oss-20b:free", # 404
    # "arcee-ai/trinity-mini:free", # invalid JSON
    # "xiaomi/mimo-v2-flash:free", # стала платной
    # "mistralai/devstral-2512:free", # стала платной
    # "nvidia/nemotron-nano-9b-v2:free", # плохо себя показала
    # "meta-llama/llama-3.3-70b-instruct:free", # плохо себя показала
    # "nvidia/nemotron-nano-12b-v2-vl:free", # плохо себя показала,
    # "deepseek/deepseek-r1-0528:free", # invalid JSON
    # "meta-llama/llama-3.2-3b-instruct:free", # rate-limited
    # "nousresearch/hermes-3-llama-3.1-405b:free", # rate-limited
    # "qwen/qwen3-4b:free" # rate-limited
]

# %%
for indicator in indicators:
    for sheet in indicator["sheets"]:
        for model in or_models:
            call_llm_save_result_and_validate(
                base_url="https://openrouter.ai/api/v1",
                api_key=or_key,
                model=model,
                indicator_name=f"{indicator['name']}/{sheet}",
            )
# Out:
# ВРП/2 | stepfun/step-3.5-flash:free
# response content len: 43815, duration: 283s
# result saved to ./dataset/ВРП/2\outputs\stepfun-step-3.5-flash\2026-02-26_11-45-09.json
# 88 неточностей
#
# ВРП/2 | nvidia/nemotron-3-nano-30b-a3b:free
# response content len: 51969, duration: 415s
# Произошла ошибка: Expecting ',' delimiter: line 741 column 63 (char 50527)
#
# ВРП/2 | z-ai/glm-4.5-air:free
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 4
#       2 for sheet in indicator["sheets"]:
#       3     for model in models:
# ----> 4         call_llm_save_result_and_validate(
#       5             base_url="https://openrouter.ai/api/v1",
#       6             api_key=or_key,
#       7             model=model,
#       8             indicator_name=f"{indicator['name']}/{sheet}",
#       9         )
#
# Cell In[7], line 15, in call_llm_save_result_and_validate(base_url, api_key, model, indicator_name)
#      12     expected_data = json.loads(file.read())
#      14 start = time.perf_counter()
# ---> 15 content = call_llm(base_url, api_key, model, system_message, data)
#      16 end = time.perf_counter()
#      18 print(f"response content len: {len(content)}, duration: {int(end - start)}s")
#
# Cell In[4], line 8, in call_llm(base_url, api_key, model, system_message, prompt)
#       1 def call_llm(base_url, api_key, model, system_message, prompt):
#       2     client = OpenAI(
#       3         base_url=base_url,
#       4         api_key=api_key,
#       5         timeout=1800
#       6     )
# ----> 8     completion = client.chat.completions.create(
#       9         model=model,
#      10         messages=[
#      11             {"role": "system", "content": system_message},
#      12             {"role": "user", "content": prompt},
#      13         ],
#      14         # temperature=0,
#      15     )
#      17     return completion.choices[0].message.content
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_client.py:928, in Client.send(self, request, stream, auth, follow_redirects)
#     926 except BaseException as exc:
#     927     response.close()
# --> 928     raise exc
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_client.py:922, in Client.send(self, request, stream, auth, follow_redirects)
#     920 try:
#     921     if not stream:
# --> 922         response.read()
#     924     return response
#     926 except BaseException as exc:
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_models.py:881, in Response.read(self)
#     877 """
#     878 Read and return the response content.
#     879 """
#     880 if not hasattr(self, "_content"):
# --> 881     self._content = b"".join(self.iter_bytes())
#     882 return self._content
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ### HuggingFace

# %%
hf_models = [
    # "Qwen/Qwen3-Coder-Next:novita",
    "google/gemma-3-27b-it:featherless-ai",
    # "XiaomiMiMo/MiMo-V2-Flash:novita"
]

# %%
for model in hf_models:
    for indicator in indicators:
        for sheet in indicator["sheets"]:
            call_llm_save_result_and_validate(
                base_url="https://router.huggingface.co/v1",
                api_key=hf_token,
                model=model,
                indicator_name=f"{indicator['name']}/{sheet}",
            )
# Out:
# ВВП/1 | google/gemma-3-27b-it:featherless-ai
# response content len: 1503, duration: 44s
# Произошла ошибка: Expecting value: line 66 column 5 (char 1136)
#
# ВВП/2 | google/gemma-3-27b-it:featherless-ai
# response content len: 1251, duration: 36s
# result saved to ./dataset/ВВП/2\outputs\google-gemma-3-27b-it\2026-02-26_18-34-39.json
# Произошла ошибка: 'list' object has no attribute 'keys'
#
# ВВП/3 | google/gemma-3-27b-it:featherless-ai
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[119], line 4
#       2 for indicator in indicators:
#       3     for sheet in indicator["sheets"]:
# ----> 4         call_llm_save_result_and_validate(
#       5             base_url="https://router.huggingface.co/v1",
#       6             api_key=hf_token,
#       7             model=model,
#       8             indicator_name=f"{indicator['name']}/{sheet}",
#       9         )
#
# Cell In[115], line 15, in call_llm_save_result_and_validate(base_url, api_key, model, indicator_name)
#      12     expected_data = json.loads(file.read())
#      14 start = time.perf_counter()
# ---> 15 content = call_llm(base_url, api_key, model, system_message, data)
#      16 end = time.perf_counter()
#      18 print(f"response content len: {len(content)}, duration: {int(end - start)}s")
#
# Cell In[4], line 8, in call_llm(base_url, api_key, model, system_message, prompt)
#       1 def call_llm(base_url, api_key, model, system_message, prompt):
#       2     client = OpenAI(
#       3         base_url=base_url,
#       4         api_key=api_key,
#       5         timeout=1800
#       6     )
# ----> 8     completion = client.chat.completions.create(
#       9         model=model,
#      10         messages=[
#      11             {"role": "system", "content": system_message},
#      12             {"role": "user", "content": prompt},
#      13         ],
#      14         # temperature=0,
#      15     )
#      17     return completion.choices[0].message.content
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_client.py:928, in Client.send(self, request, stream, auth, follow_redirects)
#     926 except BaseException as exc:
#     927     response.close()
# --> 928     raise exc
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_client.py:922, in Client.send(self, request, stream, auth, follow_redirects)
#     920 try:
#     921     if not stream:
# --> 922         response.read()
#     924     return response
#     926 except BaseException as exc:
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_models.py:881, in Response.read(self)
#     877 """
#     878 Read and return the response content.
#     879 """
#     880 if not hasattr(self, "_content"):
# --> 881     self._content = b"".join(self.iter_bytes())
#     882 return self._content
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\Desktop\projects\llm-testing\venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Метрики

# %%
def load_json(path: Path) -> List[dict]:
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

# %%
def get_latest_json_file(model_dir: Path) -> Path:
    """
    Возвращает самый новый JSON файл в папке модели.
    Имя файла уже содержит дату → можно просто взять max().
    """
    json_files = list(model_dir.glob("*.json"))
    if not json_files:
        return None
    return max(json_files)  # по имени (дата в формате YYYY-MM-DD_HH-MM-SS)

# %%
def to_record_dict(data: list, key_fields: list):
    """
    Преобразует список объектов в словарь:
    (dynamic key) -> value

    key_fields: например
        ["subject", "year"]
        ["subject", "year", "month"]
        ["subject", "year", "month", "day"]
    """
    records = {}

    for item in data:
        try:
            key = tuple(item.get(field) for field in key_fields)
        except KeyError as e:
            raise ValueError(f"Missing key field {e} in item {item}")

        records[key] = item["value"]

    return records

# %%
def compute_metrics(expected: Dict, predicted: Dict):
    expected_keys = set(expected.keys())
    predicted_keys = set(predicted.keys())

    tp_keys = expected_keys & predicted_keys
    fp_keys = predicted_keys - expected_keys
    fn_keys = expected_keys - predicted_keys

    TP = len(tp_keys)
    FP = len(fp_keys)
    FN = len(fn_keys)

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = (
        2 * precision * recall / (precision + recall)
        if (precision + recall) > 0
        else 0
    )

    # === Value metrics ===
    valid_tp_keys = set()
    abs_errors = []
    exact_matches = 0
    
    for key in tp_keys:
        true_val = expected[key]
        pred_val = predicted[key]
    
        if pred_val is None:
            # считаем как отсутствие значения → не включаем в TP для value-метрик
            continue
    
        valid_tp_keys.add(key)
    
        if true_val == pred_val:
            exact_matches += 1
    
        abs_errors.append(abs(true_val - pred_val))
    
    # пересчитываем TP для value-метрик
    TP_values = len(valid_tp_keys)
    
    value_accuracy = exact_matches / TP_values if TP_values > 0 else 0
    mae = sum(abs_errors) / len(abs_errors) if abs_errors else 0
    rmse = (
        math.sqrt(sum((e ** 2 for e in abs_errors)) / len(abs_errors))
        if abs_errors
        else 0
    )

    return {
        "TP": TP,
        "FP": FP,
        "FN": FN,
        "precision": round(precision, 4),
        "recall": round(recall, 4),
        "f1": round(f1, 4),
        # opt
        "value_accuracy": round(value_accuracy, 4),
        "mae": round(mae, 6),
        "rmse": round(rmse, 6),
    }

# %%
def evaluate(base_path: Path, target_models: list, indicators: list):
    results = []

    for indicator in indicators:
        indicator_name = indicator["name"]
        sheets = indicator["sheets"]
        key_fields = indicator["key_fields"]

        indicator_path = base_path / indicator_name
        if not indicator_path.exists():
            continue

        for sheet in sheets:
            sheet_name = str(sheet)
            sheet_path = indicator_path / sheet_name

            expected_path = sheet_path / "expected.json"
            outputs_path = sheet_path / "outputs"

            if not expected_path.exists() or not outputs_path.exists():
                continue

            try:
                expected_data = load_json(expected_path)
                expected_records = to_record_dict(expected_data, key_fields)
            except Exception as e:
                print(f"[ERROR] Failed to load expected: {expected_path}: {e}")
                continue

            for model_name in target_models:
                # print(f"Evaluating {indicator_name} | {sheet} | {model_name}\n")
                model_dir = outputs_path / model_name

                if not model_dir.exists():
                    continue

                latest_file = get_latest_json_file(model_dir)
                if not latest_file:
                    continue

                try:
                    predicted_data = load_json(latest_file)
                    predicted_records = to_record_dict(predicted_data, key_fields)
                except Exception as e:
                    print(f"[ERROR] Failed to load prediction: {latest_file}: {e}")
                    continue

                metrics = compute_metrics(expected_records, predicted_records)

                results.append({
                    "indicator": indicator_name,
                    "sheet": sheet_name,
                    "model": model_name,
                    **metrics
                })

    return results

# %%
def aggregate_by_model(results):
    aggregated = defaultdict(lambda: {
        "TP": 0,
        "FP": 0,
        "FN": 0,
        "f1_list": [],
        "value_accuracy_list": [],
        "mae_list": [],
        "rmse_list": []
    })

    for r in results:
        model = r["model"]

        aggregated[model]["TP"] += r["TP"]
        aggregated[model]["FP"] += r["FP"]
        aggregated[model]["FN"] += r["FN"]

        aggregated[model]["f1_list"].append(r["f1"])
        aggregated[model]["value_accuracy_list"].append(r["value_accuracy"])
        aggregated[model]["mae_list"].append(r["mae"])
        aggregated[model]["rmse_list"].append(r["rmse"])

    final_scores = {}

    for model, data in aggregated.items():
        TP = data["TP"]
        FP = data["FP"]
        FN = data["FN"]

        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        recall = TP / (TP + FN) if (TP + FN) > 0 else 0
        micro_f1 = (
            2 * precision * recall / (precision + recall)
            if (precision + recall) > 0
            else 0
        )

        final_scores[model] = {
            # micro metrics
            "micro_precision": round(precision, 4),
            "micro_recall": round(recall, 4),
            "micro_f1": round(micro_f1, 4),

            # macro metrics
            "macro_f1": round(sum(data["f1_list"]) / len(data["f1_list"]), 4),
            "macro_value_accuracy": round(sum(data["value_accuracy_list"]) / len(data["value_accuracy_list"]), 4),

            # средние ошибки
            "avg_mae": round(sum(data["mae_list"]) / len(data["mae_list"]), 6),
            "avg_rmse": round(sum(data["rmse_list"]) / len(data["rmse_list"]), 6),
        }

    return final_scores

# %%
base_path = Path("dataset")

target_models = [
    "Qwen-Qwen3-Coder-Next",
    "stepfun-step-3.5-flash",
    "nvidia-nemotron-3-nano-30b-a3b",
    "z-ai-glm-4.5-air",
    "arcee-ai-trinity-large-preview",
]

# %%
all_results = evaluate(base_path, target_models, indicators)

model_scores = aggregate_by_model(all_results)

for model, metrics in model_scores.items():
    print(f"MODEL: {model}")
    for k, v in metrics.items():
        print(f"{k}: {v}")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       1 base_path = Path("dataset")
#       3 target_models = [
#       4     "Qwen-Qwen3-Coder-Next",
#       5     "stepfun-step-3.5-flash",
#    (...)      8     "arcee-ai-trinity-large-preview",
#       9 ]
# ---> 11 all_results = evaluate(base_path, target_models, indicators)
#      13 model_scores = aggregate_by_model(all_results)
#      15 for model, metrics in model_scores.items():
#
# NameError: name 'evaluate' is not defined

# %% [markdown]
# ### Детальный просмотр несоответствий

# %%
def compute_basic_metrics(expected: Dict, predicted: Dict):
    expected_keys = set(expected.keys())
    predicted_keys = set(predicted.keys())

    tp_keys = expected_keys & predicted_keys
    fp_keys = predicted_keys - expected_keys
    fn_keys = expected_keys - predicted_keys

    TP = len(tp_keys)
    FP = len(fp_keys)
    FN = len(fn_keys)

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = (
        2 * precision * recall / (precision + recall)
        if (precision + recall) > 0
        else 0
    )

    return {
        "TP": TP,
        "FP": FP,
        "FN": FN,
        "TP_KEYS": tp_keys,
        "FN_KEYS": fn_keys,
        "FP_KEYS": fp_keys,
        "precision": round(precision, 4),
        "recall": round(recall, 4),
        "f1": round(f1, 4),
    }

# %%
for indicator in indicators:
    indicator_name = indicator["name"]
    sheets = indicator["sheets"]
    key_fields = indicator["key_fields"]

    indicator_path = base_path / indicator_name
    if not indicator_path.exists():
        continue

    for sheet in sheets:
        sheet_name = str(sheet)
        sheet_path = indicator_path / sheet_name

        expected_path = sheet_path / "expected.json"
        outputs_path = sheet_path / "outputs"

        if not expected_path.exists() or not outputs_path.exists():
            continue

        try:
            expected_data = load_json(expected_path)
            expected_records = to_record_dict(expected_data, key_fields)
        except Exception as e:
            print(f"[ERROR] Failed to load expected: {expected_path}: {e}")
            continue

        for model_name in target_models:
            model_dir = outputs_path / model_name

            if not model_dir.exists():
                continue

            latest_file = get_latest_json_file(model_dir)
            if not latest_file:
                continue

            try:
                predicted_data = load_json(latest_file)
                predicted_records = to_record_dict(predicted_data, key_fields)
            except Exception as e:
                print(f"[ERROR] Failed to load prediction: {latest_file}: {e}")
                continue

            metrics = compute_basic_metrics(expected_records, predicted_records)
            
            not_matching_values = []
            for key in metrics["TP_KEYS"]:
                true_val = expected_records[key]
                pred_val = predicted_records[key]
                if true_val != pred_val:
                    not_matching_values.append([key, pred_val, true_val])
            
            print(f"{indicator_name} | {sheet} | {model_name}\n")
            print("Количество")
            print(f"- пропущенных ключей {metrics['FN']}")
            print(f"- лишних ключей {metrics['FP']}")
            print(f"- несовпадающих значений {len(not_matching_values)}\n")

            if (len(metrics["FN_KEYS"]) > 0):
                print("Пропущенные ключи:")
                for key in metrics["FN_KEYS"]:
                    print(key)
                print()

            if (len(metrics["FP_KEYS"]) > 0):
                print("Лишние ключи:")
                for key in metrics["FP_KEYS"]:
                    print(key)
                print()
            
            if len(not_matching_values) > 0:
                print("Несовпадающие значения:")
                print(
                    tabulate(
                        not_matching_values,
                        headers=["Key", "Pred", "True"],
                        tablefmt="grid"
                    )
                )
                print()
                
            print("--------------------------------------------------\n")
# Out:
# ВВП | 1 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 1 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 1 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 1 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 1 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 2 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 2 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 2 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 2 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 2 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 3 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 3 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 3 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 3 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# ВВП | 3 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Индекс потребительских цен (за рассматриваемый период) | Данные | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Индекс потребительских цен (за рассматриваемый период) | Данные | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Индекс потребительских цен (за рассматриваемый период) | Данные | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 192
# - лишних ключей 192
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('Владимирская область', 2024, 3)
# ('Курганская область', 2025, 3)
# ('Свердловская область', 2025, 3)
# ('Воронежская область', 2025, 3)
# ('Республика Хакасия', 2025, 3)
# ('Томская область', 2024, 3)
# ('Республика Бурятия', 2024, 3)
# ('Сахалинская область', 2024, 3)
# ('Волгоградская область', 2025, 3)
# ('Приволжский федеральный округ', 2024, 3)
# ('Ставропольский край', 2024, 3)
# ('Северо-Западный федеральный округ', 2024, 3)
# ('Мурманская область', 2025, 3)
# ('Новгородская область', 2025, 3)
# ('Республика Саха (Якутия)', 2024, 3)
# ('Камчатский край', 2025, 3)
# ('Белгородская область', 2025, 3)
# ('Самарская область', 2025, 3)
# ('Смоленская область', 2025, 3)
# ('Калужская область', 2025, 3)
# ('Ненецкий автономный округ (Архангельская область)', 2025, 3)
# ('Чукотский автономный округ', 2024, 3)
# ('Хабаровский край', 2024, 3)
# ('Чеченская Республика', 2024, 3)
# ('Саратовская область', 2025, 3)
# ('Владимирская область', 2025, 3)
# ('Нижегородская область', 2025, 3)
# ('Магаданская область', 2025, 3)
# ('Республика Алтай', 2025, 3)
# ('Липецкая область', 2024, 3)
# ('Тюменская область (кроме Ханты-Мансийского автономного округа-Югры и Ямало-Ненецкого автономного округа)', 
# ('Приволжский федеральный округ', 2024, 1)
# ('Алтайский край', 2024, 1)
# ('Саратовская область', 2024, 1)
# ('Нижегородская область', 2024, 1)
# ('Тульская область', 2025, 1)
# ('Тамбовская область', 2025, 1)
# ('Республика Татарстан (Татарстан)', 2025, 1)
# ('Пензенская область', 2024, 1)
# ('Костромская область', 2025, 1)
# ('Сибирский федеральный округ (с 03.11.2018)', 2025, 1)
# ('Республика Марий Эл', 2025, 1)
# ('Российская Федерация без учета новых субъектов (с 01.01.2023)', 2024, 1)
# ('Город Санкт-Петербург город федерального значения', 2025, 1)
# ('Республика Крым', 2025, 1)
# ('Ямало-Ненецкий автономный округ (Тюменская область)', 2025, 1)
# ('Уральский федеральный округ', 2025, 1)
# ('Амурская область', 2025, 1)
# ('Московская область', 2024, 1)
# ('Ивановская область', 2024, 1)
# ('Архангельская область', 2024, 1)
# ('Ульяновская область', 2025, 1)
# ('Новосибирская область', 2025, 1)
# ('Рязанская область', 2024, 1)
# ('Сахалинская область', 2025, 1)
# ('Приморский край', 2024, 1)
# ('Центральный федеральный округ', 2024, 1)
# ('Российская Федерация без учета новых субъектов (с 01.01.2023)', 2025, 1)
# ('Красноярский край', 2024, 1)
# ('Челябинская область', 2024, 1)
# ('Краснодарский край', 2025, 1)
# ('Республика Карелия', 2024, 1)
# ('Иркутская область', 2025, 1)
# ('Брянская область', 2025, 1)
# ('Ленинградская область', 2024, 1)
# ('Республика Мордовия', 2024, 1)
# ('Ростовская область', 2025, 1)
# ('Омская область', 2025, 1)
# ('Республика Калмыкия', 2024, 1)
# ('Вологодская область', 2024, 1)
# ('Владимирская область', 2024, 1)
# ('Курганская область', 2025, 1)
# ('Свердловская область', 2025, 1)
# ('Воронежская область', 2025, 1)
# ('Республика Хакасия', 2025, 1)
# ('Республика Бурятия', 2024, 1)
# ('Республика Дагестан', 2025, 1)
# ('Волгоградская область', 2025, 1)
# ('Ставропольский край', 2024, 1)
# ('Тверская область', 2024, 1)
# ('Северо-Западный федеральный округ', 2024, 1)
# ('Мурманская область', 2025, 1)
# ('Новгородская область', 2025, 1)
# ('Кировская область', 2024, 1)
# ('Республика Саха (Якутия)', 2024, 1)
# ('Камчатский край', 2025, 1)
# ('Белгородская область', 2025, 1)
# ('Самарская область', 2025, 1)
# ('Ярославская область', 2025, 1)
#
# --------------------------------------------------
#
# Индекс потребительских цен (за рассматриваемый период) | Данные | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Индекс потребительских цен (за рассматриваемый период) | Данные | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Индекс производства (оперативные данные) | Данные | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Индекс производства (оперативные данные) | Данные | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Индекс производства (оперативные данные) | Данные | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 1
# - лишних ключей 1
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('Тюменская область (кроме Ханты-Мансийского автономного округа-Югры и Ямало-Ненецкого автономного округа)', 2023, 6)
#
# Лишние ключи:
# ('Тюменская область (кроме Ханты-Мансийского автономного округa-Югры и Ямало-Ненецкого автономного округа)', 2023, 6)
#
# --------------------------------------------------
#
# Индекс производства (оперативные данные) | Данные | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Индекс производства (оперативные данные) | Данные | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Непродовольственные товары (за рассматриваемый период) | Данные | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Непродовольственные товары (за рассматриваемый период) | Данные | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Непродовольственные товары (за рассматриваемый период) | Данные | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Непродовольственные товары (за рассматриваемый период) | Данные | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Непродовольственные товары (за рассматриваемый период) | Данные | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 96
# - лишних ключей 0
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('
# ('Еврейская авт. область', 2025, 6)
# ('Курская область', 2025, 6)
# ('Дальневосточный федеральный округ', 2025, 7)
# ('Приморский край', 2025, 6)
# ('Центральный федеральный округ', 2024, 7)
# ('Ярославская область', 2024, 7)
# ('Республика Карелия', 2024, 7)
# ('Ставропольский край', 2025, 7)
# ('Республика Ингушетия', 2025, 6)
# ('Республика Мордовия', 2024, 7)
# ('Ленинградская область', 2025, 6)
# ('Омская область', 2025, 7)
# ('Республика Калмыкия', 2025, 6)
# ('Республика Ингушетия', 2024, 7)
# ('Магаданская область', 2024, 7)
# ('Северо-Кавказский федеральный округ', 2025, 6)
# ('Чеченская Республика', 2025, 7)
# ('Приволжский федеральный округ', 2025, 6)
# ('Курганская область', 2025, 7)
# ('Калужская область', 2024, 7)
# ('Псковская область', 2025, 6)
# ('Воронежская область', 2025, 7)
# ('Пензенская область', 2025, 6)
# ('Томская область', 2024, 7)
# ('Республика Бурятия', 2025, 6)
# ('Российская Федерация', 2025, 6)
# ('Чувашская Республика', 2025, 7)
# ('Волгоградская область', 2025, 7)
# ('Приволжский федеральный округ', 2024, 7)
# ('Мурманская область', 2025, 7)
# ('Кировская область', 2025, 6)
# ('Пермский край', 2025, 6)
# ('Самарская область', 2025, 7)
# ('Московская область', 2025, 6)
# ('Калужская область', 2025, 7)
# ('Хабаровский край', 2024, 7)
# ('Липецкая область', 2025, 6)
# ('Тамбовская область', 2025, 6)
# ('Саратовская область', 2025, 7)
# ('Красноярский край', 2025, 6)
# ('Ульяновская область', 2025, 7)
# ('Челябинская область', 2025, 6)
# ('Липецкая область', 2024, 7)
# ('Республика Алтай', 2025, 7)
# ('Сахалинская область', 2025, 7)
# ('Республика Коми', 2025, 6)
# ('Тюменская область без авт. округов', 2025, 7)
# ('Красноярский край', 2024, 7)
# ('Челябинская область', 2024, 7)
# ('Удмуртская Республика', 2024, 7)
# ('Иркутская область', 2025, 7)
# ('Брянская область', 2025, 7)
# ('Ленинградская область', 2024, 7)
# ('Кемеровская область', 2024, 7)
# ('Республика Калмыкия', 2024, 7)
# ('Ставропольский край', 2025, 6)
# ('Свердловская область', 2025, 7)
# ('Архангельская область', 2025, 7)
# ('Еврейская авт. область', 2025, 7)
# ('Курская область', 2025, 7)
# ('Республика Дагестан', 2025, 7)
# ('в том числе: Ханты-Мансийский авт. округ - Югра', 2025, 6)
# ('Забайкальский край', 2024, 7)
# ('Ставропольский край', 2024, 7)
# ('Республика Башкортостан', 2025, 7)
# ('Кировская область', 2024, 7)
# ('Приморский край', 2025, 7)
# ('Чеченская Республика', 2025, 6)
# ('Белгородская область', 2025, 7)
# ('Курганская область', 2025, 6)
# ('Смоленская область', 2025, 7)
# ('Волгоградская область', 2025, 6)
# ('Чеченская Республика', 2024, 7)
# ('Курганская область', 2024, 7)
# ('Ямало-Ненецкий авт. округ', 2025, 6)
# ('Владимирская область', 2025, 7)
# ('Костромская область', 2025, 6)
# ('Самарская область', 2025, 6)
# ('Республика Марий Эл', 2025, 6)
# ('Чувашская Республика', 2024, 7)
# ('Северо-Кавказский федеральный округ', 2025, 7)
# ('Пензенская область', 2025, 7)
# ('Республика Бурятия', 2025, 7)
# ('Республика Тыва', 2025, 7)
# ('Уральский федеральный округ', 2024, 7)
# ('Сибирский федеральный округ', 2025, 7)
# ('Тамбовская область', 2024, 7)
# ('Алтайский край', 2025, 7)
# ('Республика Татарстан', 2025, 7)
# ('г. Москва', 2025, 7)
# ('Ульяновская область', 2025, 6)
# ('Новосибирская область', 2025, 6)
# ('Сахалинская область', 2025, 6)
# ('Московская область', 2025, 7)
# ('Тюменская область без авт. округов', 2025, 6)
# ('Ульяновская область', 2024, 7)
# ('Иркутская область', 2025, 6)
# ('Брянская область', 2025, 6)
# ('Дальневосточный федеральный округ', 2024, 7)
# ('Тюменская область без авт. округов', 2024, 7)
# ('Красноярский край', 2025, 7)
# ('Псковская область', 2024, 7)
# ('Омская область', 2024, 7)
# ('Иркутская область', 2024, 7)
# ('Свердловская область', 2025, 6)
# ('Воронежская область', 2024, 7)
# ('г. Севастополь', 2024, 7)
# ('Республика Хакасия', 2024, 7)
# ('Пермский край', 2024, 7)
# ('Волгоградская область', 2024, 7)
# ('Республика Дагестан', 2025, 6)
# ('Астраханская область', 2025, 7)
# ('Мурманская область', 2024, 7)
# ('Республика Башкортостан', 2025, 6)
# ('Камчатский край', 2025, 6)
# ('Новгородская область', 2025, 6)
# ('Северо-Западный федеральный округ', 2025, 7)
# ('Белгородская область', 2025, 6)
# ('Самарская область', 2024, 7)
# ('Курская область', 2024, 7)
# ...
# | ('Московская область', 2025, 8)                         |  972.38 |  8622.3  |
# +---------------------------------------------------------+---------+----------+
# | ('Ивановская область', 2025, 8)                         |   35.42 |   367.8  |
# +---------------------------------------------------------+---------+----------+
# | ('Рязанская область', 2025, 8)                          |   34.15 |   425.89 |
# +---------------------------------------------------------+---------+----------+
# | ('Центральный федеральный округ', 2025, 8)              | 2531.17 | 19909.4  |
# +---------------------------------------------------------+---------+----------+
# | ('Красноярский край', 2025, 8)                          |  105.97 |   882.97 |
# +---------------------------------------------------------+---------+----------+
# | ('Челябинская область', 2025, 8)                        |  108.81 |  1299.38 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Карелия', 2025, 8)                         |   16.95 |   241.67 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Мордовия', 2025, 8)                        |   38.8  |   157.24 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Коми', 2025, 8)                            |   27.74 |   146.56 |
# +---------------------------------------------------------+---------+----------+
# | ('Вологодская область', 2025, 8)                        |   36.18 |   563.48 |
# +---------------------------------------------------------+---------+----------+
# | ('Еврейская автономная область', 2025, 8)               |    1.71 |    26.09 |
# +---------------------------------------------------------+---------+----------+
# | ('Архангельская область (кроме Ненецкого АО)', 2025, 8) |   37.35 |   280.78 |
# +---------------------------------------------------------+---------+----------+
# | ('Чувашская Республика - Чувашия', 2025, 8)             |   58.12 |   568.37 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Калмыкия', 2025, 8)                        |   12.04 |    71.73 |
# +---------------------------------------------------------+---------+----------+
# | ('Ненецкий АО', 2025, 8)                                |    1.59 |    22.18 |
# +---------------------------------------------------------+---------+----------+
# | ('Ставропольский край', 2025, 8)                        |  121.01 |  1524.57 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Саха (Якутия)', 2025, 8)                   |   68.13 |   483.94 |
# +---------------------------------------------------------+---------+----------+
# | ('Псковская область', 2025, 8)                          |   26.25 |   189.29 |
# +---------------------------------------------------------+---------+----------+
# | ('Забайкальский край', 2025, 8)                         |   19.56 |   288.12 |
# +---------------------------------------------------------+---------+----------+
# | ('Кировская область', 2025, 8)                          |   44.22 |   321.87 |
# +---------------------------------------------------------+---------+----------+
# | ('Тверская область', 2025, 8)                           |   93.75 |   627.88 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Северная Осетия-Алания', 2025, 8)          |   16.11 |   350.79 |
# +---------------------------------------------------------+---------+----------+
# | ('Хабаровский край', 2025, 8)                           |   43.7  |   351.86 |
# +---------------------------------------------------------+---------+----------+
# | ('Чеченская Республика', 2025, 8)                       |  342.11 |  1289.77 |
# +---------------------------------------------------------+---------+----------+
# | ('Кемеровская область - Кузбасс', 2025, 8)              |   64.27 |   445.89 |
# +---------------------------------------------------------+---------+----------+
# | ('Чукотский АО', 2025, 8)                               |    0.59 |     2.62 |
# +---------------------------------------------------------+---------+----------+
# | ('г.Москва', 2025, 8)                                   |  600.99 |  3424.9  |
# +---------------------------------------------------------+---------+----------+
# | ('Липецкая область', 2025, 8)                           |   51.65 |   332.88 |
# +---------------------------------------------------------+---------+----------+
# | ('Тульская область', 2025, 8)                           |   84.03 |   542.5  |
# +---------------------------------------------------------+---------+----------+
# | ('Тамбовская область', 2025, 8)                         |   31.18 |   252.76 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Татарстан (Татарстан)', 2025, 8)           |  248.47 |  2847.9  |
# +---------------------------------------------------------+---------+----------+
# | ('Тюменская область (без автономных округов)', 2025, 8) |  194.85 |  1538.72 |
# +---------------------------------------------------------+---------+----------+
# | ('Костромская область', 2025, 8)                        |   32.74 |   304.06 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Марий Эл', 2025, 8)                        |   42.12 |   268.92 |
# +---------------------------------------------------------+---------+----------+
# | ('Ханты-Мансийский АО-Югра', 2025, 8)                   |   78.08 |   365.32 |
# +---------------------------------------------------------+---------+----------+
# | ('Ямало-Ненецкий АО', 2025, 8)                          |   18.83 |   153.1  |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Крым', 2025, 8)                            |   81.38 |   900.81 |
# +---------------------------------------------------------+---------+----------+
# | ('Уральский федеральный округ', 2025, 8)                |  761.11 |  5820.73 |
# +---------------------------------------------------------+---------+----------+
# | ('Оренбургская область', 2025, 8)                       |   89.18 |   811.43 |
# +---------------------------------------------------------+---------+----------+
# | ('Амурская область', 2025, 8)                           |   29.7  |   155.06 |
# +---------------------------------------------------------+---------+----------+
# | ('Ульяновская область', 2025, 8)                        |   24.28 |   301.82 |
# +---------------------------------------------------------+---------+----------+
# | ('Дальневосточный федеральный округ', 2025, 8)          |  356.01 |  2878.85 |
# +---------------------------------------------------------+---------+----------+
# | ('Новосибирская область', 2025, 8)                      |  145.25 |  1521.17 |
# +---------------------------------------------------------+---------+----------+
# | ('Сахалинская область', 2025, 8)                        |   21.95 |   148.25 |
# +---------------------------------------------------------+---------+----------+
# | ('Краснодарский край', 2025, 8)                         |  406.39 |  4102.64 |
# +---------------------------------------------------------+---------+----------+
# | ('Иркутская область', 2025, 8)                          |  138.44 |  1378.69 |
# +---------------------------------------------------------+---------+----------+
# | ('Ростовская область', 2025, 8)                         |  241.81 |  1650.93 |
# +---------------------------------------------------------+---------+----------+
# | ('Омская область', 2025, 8)                             |   93.7  |   616.6  |
# +---------------------------------------------------------+---------+----------+
# | ('Курганская область', 2025, 8)                         |   21.5  |   286.17 |
# +---------------------------------------------------------+---------+----------+
# | ('Свердловская область', 2025, 8)                       |  339.04 |  2178.03 |
# +---------------------------------------------------------+---------+----------+
# | ('Воронежская область', 2025, 8)                        |  108.68 |  1132.92 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Хакасия', 2025, 8)                         |   16.52 |   348.93 |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Дагестан', 2025, 8)                        |  109.74 |  1035.01 |
# +---------------------------------------------------------+---------+----------+
# | ('Волгоградская область', 2025, 8)                      |   61.56 |   755.87 |
# +---------------------------------------------------------+---------+----------+
# | ('Мурманская область', 2025, 8)                         |    7.15 |    81.63 |
# +---------------------------------------------------------+---------+----------+
# | ('Камчатский край', 2025, 8)                            |    4.35 |    54.72 |
# +---------------------------------------------------------+---------+----------+
# | ('Новгородская область', 2025, 8)                       |   28.79 |   283.06 |
# +---------------------------------------------------------+---------+----------+
# | ('Южный федеральный округ', 2025, 8)                    |  929.42 |  8658.35 |
# +---------------------------------------------------------+---------+----------+
# | ('Белгородская область', 2025, 8)                       |   74.24 |   509.34 |
# +---------------------------------------------------------+---------+----------+
# | ('Самарская область', 2025, 8)                          |  132.37 |   933.92 |
# +---------------------------------------------------------+---------+----------+
# | ('Ярославская область', 2025, 8)                        |   73.4  |   588.53 |
# +---------------------------------------------------------+---------+----------+
# | ('Смоленская область', 2025, 8)                         |   35.41 |   349.75 |
# +---------------------------------------------------------+---------+----------+
# | ('Калужская область', 2025, 8)                          |   76.13 |   645.41 |
# +---------------------------------------------------------+---------+----------+
# | ('Саратовская область', 2025, 8)                        |   44.17 |   448.58 |
# +---------------------------------------------------------+---------+----------+
# | ('Владимирская область', 2025, 8)                       |   87.85 |   713.66 |
# +---------------------------------------------------------+---------+----------+
# | ('Нижегородская область', 2025, 8)                      |  124.55 |  1087.94 |
# +---------------------------------------------------------+---------+----------+
# | ('Магаданская область', 2025, 8)                        |    9.85 |    13.8  |
# +---------------------------------------------------------+---------+----------+
# | ('Республика Алтай', 2025, 8)                           |   24.91 |   267.78 |
# +---------------------------------------------------------+---------+----------+
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 8 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 8 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 8 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 8 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 8 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 11 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 5
# - лишних ключей 0
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('Российская Федерация', 2025, 6)
# ('Российская Федерация', 2025, 5)
# ('Российская Федерация', 2025, 8)
# ('Российская Федерация', 2025, 4)
# ('Российская Федерация', 2025, 7)
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 11 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 11 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 11 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 2
#
# Несовпадающие значения:
# +-----------------------------------+--------+--------+
# | Key                               |   Pred |   True |
# +===================================+========+========+
# | ('Российская Федерация', 2024, 3) | 210000 | 284420 |
# +-----------------------------------+--------+--------+
# | ('Российская Федерация', 2024, 5) | 200000 | 172505 |
# +-----------------------------------+--------+--------+
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 11 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 12 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 12 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 12 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 12 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Cоциально-экономическое положение | 12 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Численность и состав рабочей силы | Sheet1 | Qwen-Qwen3-Coder-Next
#
# Количество
# - пропущенных ключей 3
# - лишних ключей 0
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('в том числе: Ханты-Мансийский авт. округ - Югра', 2025)
# ('в том числе: Ненецкий авт. округ', 2025)
# ('Ямало-Ненецкий авт. округ', 2025)
#
# --------------------------------------------------
#
# Численность и состав рабочей силы | Sheet1 | stepfun-step-3.5-flash
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Численность и состав рабочей силы | Sheet1 | nvidia-nemotron-3-nano-30b-a3b
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Численность и состав рабочей силы | Sheet1 | z-ai-glm-4.5-air
#
# Количество
# - пропущенных ключей 0
# - лишних ключей 0
# - несовпадающих значений 0
#
# --------------------------------------------------
#
# Численность и состав рабочей силы | Sheet1 | arcee-ai-trinity-large-preview
#
# Количество
# - пропущенных ключей 3
# - лишних ключей 0
# - несовпадающих значений 0
#
# Пропущенные ключи:
# ('в том числе: Ханты-Мансийский авт. округ - Югра', 2025)
# ('в том числе: Ненецкий авт. округ', 2025)
# ('Ямало-Ненецкий авт. округ', 2025)
#
# --------------------------------------------------

# %% [markdown]
# ## Преобразование в различные форматы

# %%
def save_to_other_formats(sub_directory, ext, sheet_name):
    input_path = Path(f"./dataset/{sub_directory}/input.{ext}")
    try:
        print(f"Processing file: {input_path}, sheet: {sheet_name}")
        
        df = pd.read_excel(input_path, sheet_name=sheet_name)
        df = df.replace("", pd.NA)
        df = df.dropna(how="all")
        df = df.fillna("")
        
        df = df.map(
            lambda x: int(x) if isinstance(x, float) and x.is_integer()
            else round(x, 2) if isinstance(x, (int, float))
            else x
        )
        df = df.map(lambda x: x.replace('\n', ' ') if isinstance(x, str) else x)
        df = df.map(lambda x: " ".join(x.split()) if isinstance(x, str) else x)
        df = df.rename(columns=lambda x: "" if str(x).startswith("Unnamed") else x)
        df = df.map(lambda x: str(x).strip())

        output_dir = Path(f"./dataset/{sub_directory}/{sheet_name}")
        output_dir.mkdir(parents=True, exist_ok=True)
        
        df.to_csv(output_dir / "input.csv", index=False)
        df.to_html(output_dir / "input.html", index=False)
        df.to_markdown(output_dir / "input.md", index=False)

        print(f"Files saved in {output_dir}")
    except Exception as e:
        print(f"Error processing {input_path}: {e}")

# %%
for indicator in indicators:
    for sheet in indicator["sheets"]:
        save_to_other_formats(indicator["name"], "xlsx", sheet)
# Out:
# Processing file: dataset\ВРП\input.xlsx, sheet: 1
# Files saved in dataset\ВРП\1
# Processing file: dataset\ВРП\input.xlsx, sheet: 2
# Files saved in dataset\ВРП\2
# Processing file: dataset\ВРП\input.xlsx, sheet: 3
# Files saved in dataset\ВРП\3
# Processing file: dataset\ВРП\input.xlsx, sheet: 4
# Files saved in dataset\ВРП\4

# %%
save_to_other_formats("ВРП", "xlsx", "12")
# Out:
# Processing file: dataset\ВРП\input.xlsx, sheet: 12
# Files saved in dataset\ВРП\12

# %% [markdown]
# ### Составление expected для больших файлов

# %%
input_csv = "./dataset/ВРП/12/input.csv"
output_json = "./dataset/ВРП/12/expected.json"
years_row_number = 2

results = []

with open(input_csv, newline="", encoding="utf-8") as f:
    reader = csv.reader(f)
    rows = list(reader)

years_row = rows[years_row_number]

years = [y for y in years_row[1:] if y.strip() != ""]

data_rows = rows[years_row_number+1:]

for row in data_rows:
    if not row or row[0].strip() == "":
        continue

    subject = row[0].strip()

    # Пропускаем строки, которые не являются регионами
    # if any(keyword in subject.lower() for keyword in ["округ", "валовой"]):
    #     continue

    values = row[1:]

    for year, value in zip(years, values):
        value = value.strip()
        if value == "":
            continue

        value = float(value.replace(",", ".").replace(" ", ""))

        results.append({
            "subject": subject,
            "year": year,
            "month": None,
            "day": None,
            "value": value
        })

with open(output_json, "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)
    print("Saved!")
# Out:
# Saved!
